# %%
import tensorflow.compat.v1 as tf

tf.config.set_soft_device_placement(True)
# tf.debugging.set_log_device_placement(True)
# from sklearn.metrics import confusion_matrix
import numpy as np
# from scipy.io import loadmat
import os
# from functools import reduce
# from scipy import signal
import pandas as pd
# from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow import keras as K
from tensorflow.keras.layers import Add, Dense, Activation, Flatten, concatenate, Input, Dropout, LSTM, Conv2D, MaxPooling2D, Conv1D, MaxPooling1D, BatchNormalization, PReLU, ELU, ReLU
from tensorflow.keras.models import Sequential, Model, load_model
import matplotlib.pyplot as plt
# import datetime
# get_ipython().run_line_magic('load_ext', 'tensorboard')
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# get_ipython().run_line_magic('matplotlib', 'inline')
# from collections import Counter 
np_load_old = np.load
# from tensorflow.keras.utils import plot_model
from tensorflow.keras.initializers import glorot_uniform
# modify the default parameters of np.load
np.load = lambda *a,**k: np_load_old(*a, allow_pickle=True, **k)
np.random.seed(42)
tf.set_random_seed(42)
from sklearn.metrics import classification_report
import argparse
import h5py

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import itertools

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.figure(figsize=(15,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=36)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=30)
    plt.yticks(tick_marks, classes, fontsize=30)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black", fontsize=28)

    plt.tight_layout()
    plt.ylabel('True label', fontsize=30)
    plt.xlabel('Predicted label', fontsize=30)

# %% [markdown]
# ## Load in data

# %%
# load new train, validation, and test datasets
loadPath = '/home/sz4544/EEG-motor-imagery-main/project/'
os.makedirs(os.path.join(loadPath, "models"), exist_ok=True)
bestModel = '/home/sz4544/EEG-motor-imagery-main/project/models/baseline_tr1800-val360ts_2CNN.keras'


f_train = h5py.File(os.path.join(loadPath, "train1800_raw_EEG.h5"), "r")
tr_data = f_train['data'][:]
ytr = f_train['tasks'][:]
tr_subjects = f_train['subjects'][:]

f_valid = h5py.File(os.path.join(loadPath, "valid360_raw_EEG.h5"), "r")
val_data = f_valid['data'][:]
yval = f_valid['tasks'][:]
val_subjects = f_valid['subjects'][:]

f_test = h5py.File(os.path.join(loadPath, "test360_raw_EEG.h5"), "r")
ts_data = f_test['data'][:]
yts = f_test['tasks'][:]
ts_subjects = f_test['subjects'][:]

# %% [markdown]
# ## Normalization

# %%
# flatten and reshape data
xtr_s_flattened = np.squeeze(tr_data).ravel().reshape((-1, 64))
xval_s_flattened = np.squeeze(val_data).ravel().reshape((-1, 64))
xts_s_flattened = np.squeeze(ts_data).ravel().reshape((-1, 64))
print(xtr_s_flattened.shape)
print(xval_s_flattened.shape)
print(xts_s_flattened.shape)

# normalize data
scaler = StandardScaler()
Ztr_temp = scaler.fit_transform(xtr_s_flattened)
Zval_temp = scaler.transform(xval_s_flattened)
Zts_temp = scaler.transform(xts_s_flattened)

# flatten and reshape data back
Ztr = np.squeeze(Ztr_temp).ravel().reshape((-1, 640, 64))
Zval = np.squeeze(Zval_temp).ravel().reshape((-1, 640, 64))
Zts = np.squeeze(Zts_temp).ravel().reshape((-1, 640, 64))
print(Ztr.shape)
print(Zval.shape)
print(Zts.shape)
# Out:
# (1152000, 64)
# (230400, 64)
# (230400, 64)
# (1800, 640, 64)
# (360, 640, 64)
# (360, 640, 64)

# %%
x_train = Ztr[..., np.newaxis]
x_valid = Zval[..., np.newaxis]
x_test = Zts[..., np.newaxis]
y_train = pd.get_dummies(ytr).values
y_valid = pd.get_dummies(yval).values
y_test = pd.get_dummies(yts).values

# %% [markdown]
# ## Model architecture

# %%
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# Number of devices: 1

# %%
with strategy.scope():
    nodes = 640
    inputs = Input(shape=(nodes, 64, 1))

    conv1 = Conv2D(8, (15,9), strides=(2,1), kernel_initializer = glorot_uniform(seed=42))(inputs)
    batch1 = BatchNormalization()(conv1)
    prelu1 = PReLU()(batch1)
    maxpool1 = MaxPooling2D((2,2))(prelu1)
    conv2 = Conv2D(16, (15,9), strides=(2,1), kernel_initializer = glorot_uniform(seed=42))(maxpool1)
    batch2 = BatchNormalization()(conv2)
    prelu2 = PReLU()(batch2)
    # maxpool2 = MaxPooling2D((5,1))(prelu2)

    flat = Flatten()(prelu2)
    dense1 = Dense(16, activation='sigmoid', kernel_initializer = glorot_uniform(seed=42))(flat)
    drop1 = Dropout(0.2)(dense1)
    predictions = Dense(4, activation='softmax', kernel_initializer = glorot_uniform(seed=42))(drop1)
    model = Model(inputs=inputs,outputs=predictions)
print(model.summary())
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 640, 64, 1)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 313, 56, 8)     │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 313, 56, 8)     │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ p_re_lu_4 (PReLU)               │ (None, 313, 56, 8)     │       140,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 156, 28, 8)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 71, 20, 16)     │        17,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 71, 20, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ p_re_lu_5 (PReLU)               │ (None, 71, 20, 16)     │        22,720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 22720)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 16)             │       363,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 4)              │            68 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 545,028 (2.08 MB)
#  Trainable params: 544,980 (2.08 MB)
#  Non-trainable params: 48 (192.00 B)
# None

# %%
with strategy.scope():
    opt_adam = K.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
    model.compile(loss='categorical_crossentropy', optimizer=opt_adam, metrics=['categorical_accuracy'])

es = EarlyStopping(monitor='val_categorical_accuracy', mode='max', verbose=1, patience=30)
mc = ModelCheckpoint(bestModel, monitor='val_categorical_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
history = model.fit(x=x_train, y=y_train, epochs=300, shuffle=True,
                    verbose=1, validation_data = (x_valid, y_valid), callbacks=[es, mc])
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1/300
# I0000 00:00:1773812017.588476 1644319 cuda_dnn.cc:461] Loaded cuDNN version 90800
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.2729 - loss: 1.4221INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
#
# Epoch 1: val_categorical_accuracy improved from None to 0.28889, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/baseline_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - categorical_accuracy: 0.2800 - loss: 1.3971 - val_categorical_accuracy: 0.2889 - val_loss: 1.3805
# Epoch 2/300
# 53/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.3669 - loss: 1.3025
# Epoch 2: val_categorical_accuracy did not improve from 0.28889
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.3628 - loss: 1.3050 - val_categorical_accuracy: 0.2861 - val_loss: 1.3588
# Epoch 3/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.4607 - loss: 1.2300
# Epoch 3: val_categorical_accuracy improved from 0.28889 to 0.33889, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/baseline_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.4578 - loss: 1.2285 - val_categorical_accuracy: 0.3389 - val_loss: 1.3445
# Epoch 4/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.5082 - loss: 1.1575
# Epoch 4: val_categorical_accuracy improved from 0.33889 to 0.35556, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/baseline_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.5183 - loss: 1.1455 - val_categorical_accuracy: 0.3556 - val_loss: 1.3200
# Epoch 5/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5891 - loss: 1.0521
# Epoch 5: val_categorical_accuracy improved from 0.35556 to 0.38056, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/baseline_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.5983 - loss: 1.0470 - val_categorical_accuracy: 0.3806 - val_loss: 1.2977
# Epoch 6/300
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6369 - loss: 0.9792
# Epoch 6: val_categorical_accuracy improved from 0.38056 to 0.43889, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/baseline_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - categorical_accuracy: 0.6422 - loss: 0.9730 - val_categorical_accuracy: 0.4389 - val_loss: 1.2701
# Epoch 7/300
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6720 - loss: 0.9351
# Epoch 7: val_categorical_accuracy did not improve from 0.43889
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.6750 - loss: 0.9227 - val_categorical_accuracy: 0.4222 - val_loss: 1.2527
# Epoch 8/300
# 50/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.6994 - loss: 0.8773
# Epoch 8: val_categorical_accuracy improved from 0.43889 to 0.44444, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/baseline_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.7167 - loss: 0.8568 - val_categorical_accuracy: 0.4444 - val_loss: 1.2383
# Epoch 9/300
# 55/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.7434 - loss: 0.8266
# Epoch 9: val_categorical_accuracy improved from 0.44444 to 0.46667, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/baseline_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.7522 - loss: 0.8108 - val_categorical_accuracy: 0.4667 - val_loss: 1.2351
# Epoch 10/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.8004 - loss: 0.7590
# Epoch 10: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.8056 - loss: 0.7414 - val_categorical_accuracy: 0.4556 - val_loss: 1.2387
# Epoch 11/300
# 53/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.8117 - loss: 0.7099
# Epoch 11: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.8267 - loss: 0.6971 - val_categorical_accuracy: 0.4556 - val_loss: 1.2308
# Epoch 12/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.8463 - loss: 0.6644
# Epoch 12: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.8500 - loss: 0.6526 - val_categorical_accuracy: 0.4417 - val_loss: 1.2469
# Epoch 13/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.8675 - loss: 0.6311
# Epoch 13: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.8689 - loss: 0.6213 - val_categorical_accuracy: 0.4639 - val_loss: 1.2450
# Epoch 14/300
# 50/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.8858 - loss: 0.5931
# Epoch 14: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.8872 - loss: 0.5878 - val_categorical_accuracy: 0.4472 - val_loss: 1.2533
# Epoch 15/300
# 53/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9062 - loss: 0.5462
# Epoch 15: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.8994 - loss: 0.5439 - val_categorical_accuracy: 0.4306 - val_loss: 1.2597
# Epoch 16/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9237 - loss: 0.5172
# Epoch 16: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9306 - loss: 0.5050 - val_categorical_accuracy: 0.4444 - val_loss: 1.2800
# Epoch 17/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9354 - loss: 0.4943
# Epoch 17: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9322 - loss: 0.4841 - val_categorical_accuracy: 0.4333 - val_loss: 1.2741
# Epoch 18/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9376 - loss: 0.4591
# Epoch 18: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9406 - loss: 0.4539 - val_categorical_accuracy: 0.4389 - val_loss: 1.2815
# Epoch 19/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9380 - loss: 0.4481
# Epoch 19: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9528 - loss: 0.4293 - val_categorical_accuracy: 0.4361 - val_loss: 1.2908
# Epoch 20/300
# 55/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9592 - loss: 0.4004
# Epoch 20: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9544 - loss: 0.4038 - val_categorical_accuracy: 0.4222 - val_loss: 1.2939
# Epoch 21/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9642 - loss: 0.3846
# Epoch 21: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9650 - loss: 0.3781 - val_categorical_accuracy: 0.4111 - val_loss: 1.3197
# Epoch 22/300
# 55/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9684 - loss: 0.3603
# Epoch 22: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9694 - loss: 0.3577 - val_categorical_accuracy: 0.4167 - val_loss: 1.3143
# Epoch 23/300
# 50/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9767 - loss: 0.3473
# Epoch 23: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9717 - loss: 0.3458 - val_categorical_accuracy: 0.4000 - val_loss: 1.3336
# Epoch 24/300
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9757 - loss: 0.3272
# Epoch 24: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9778 - loss: 0.3263 - val_categorical_accuracy: 0.3917 - val_loss: 1.3396
# Epoch 25/300
# 53/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9816 - loss: 0.3047
# Epoch 25: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9772 - loss: 0.3090 - val_categorical_accuracy: 0.4139 - val_loss: 1.3336
# Epoch 26/300
# 55/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9826 - loss: 0.3067
# Epoch 26: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - categorical_accuracy: 0.9817 - loss: 0.2996 - val_categorical_accuracy: 0.4000 - val_loss: 1.3319
# Epoch 27/300
# 53/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9837 - loss: 0.2847
# Epoch 27: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9833 - loss: 0.2858 - val_categorical_accuracy: 0.3917 - val_loss: 1.3523
# Epoch 28/300
# 55/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9905 - loss: 0.2776
# Epoch 28: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9889 - loss: 0.2732 - val_categorical_accuracy: 0.3972 - val_loss: 1.3444
# Epoch 29/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9888 - loss: 0.2543
# Epoch 29: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9872 - loss: 0.2526 - val_categorical_accuracy: 0.4111 - val_loss: 1.3571
# Epoch 30/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9910 - loss: 0.2454
# Epoch 30: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9906 - loss: 0.2424 - val_categorical_accuracy: 0.4028 - val_loss: 1.3562
# Epoch 31/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9895 - loss: 0.2378
# Epoch 31: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9894 - loss: 0.2358 - val_categorical_accuracy: 0.4083 - val_loss: 1.3527
# Epoch 32/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9891 - loss: 0.2354
# Epoch 32: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9894 - loss: 0.2275 - val_categorical_accuracy: 0.4139 - val_loss: 1.3556
# Epoch 33/300
# 54/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9909 - loss: 0.2236
# Epoch 33: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9917 - loss: 0.2212 - val_categorical_accuracy: 0.4083 - val_loss: 1.3706
# Epoch 34/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9944 - loss: 0.2043
# Epoch 34: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9928 - loss: 0.2067 - val_categorical_accuracy: 0.3972 - val_loss: 1.3844
# Epoch 35/300
# 49/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9954 - loss: 0.1986
# Epoch 35: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9944 - loss: 0.1941 - val_categorical_accuracy: 0.3944 - val_loss: 1.3922
# Epoch 36/300
# 55/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9932 - loss: 0.1948
# Epoch 36: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9939 - loss: 0.1992 - val_categorical_accuracy: 0.4250 - val_loss: 1.3954
# Epoch 37/300
# 50/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9955 - loss: 0.1854
# Epoch 37: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9950 - loss: 0.1841 - val_categorical_accuracy: 0.4139 - val_loss: 1.4021
# Epoch 38/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9955 - loss: 0.1777
# Epoch 38: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9950 - loss: 0.1780 - val_categorical_accuracy: 0.4028 - val_loss: 1.4099
# Epoch 39/300
# 54/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9959 - loss: 0.1667
# Epoch 39: val_categorical_accuracy did not improve from 0.46667
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9950 - loss: 0.1697 - val_categorical_accuracy: 0.4139 - val_loss: 1.4121
# Epoch 39: early stopping

# %% [markdown]
# ## Model testing

# %%
best_model = tf.keras.models.load_model(bestModel)
yhat = np.argmax(best_model.predict(x_test), axis=1)
ytrue = np.argmax(y_test, axis=1)
print('test acc: {:.2f}%'.format(np.sum(yhat == ytrue) / yts.shape[0] * 100))
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# test acc: 45.83%

# %%
target_names = ['open one hand', 'imagine open one hand', 'open both hands/feet', 'imagine open both hands/feet']
print(classification_report(ytrue, yhat, target_names=target_names, digits=4))
# Out:
#                               precision    recall  f1-score   support
#
#                open one hand     0.4898    0.2667    0.3453        90
#        imagine open one hand     0.3826    0.4889    0.4293        90
#         open both hands/feet     0.4889    0.4889    0.4889        90
# imagine open both hands/feet     0.4245    0.5000    0.4592        90
#
#                     accuracy                         0.4361       360
#                    macro avg     0.4465    0.4361    0.4307       360
#                 weighted avg     0.4465    0.4361    0.4307       360

# %%
cm = confusion_matrix(ytrue, yhat)
cm
# Out:
# array([[24, 31, 18, 17],
#        [12, 44, 12, 22],
#        [ 8, 16, 44, 22],
#        [ 5, 24, 16, 45]])

# %%
plot_confusion_matrix(cm, ['Task1', 'Task2', 'Task3', 'Task4'], normalize=True, title='Confusion matrix', cmap=plt.cm.Greys)
# Out:
# Normalized confusion matrix
# [[0.26666667 0.34444444 0.2        0.18888889]
#  [0.13333333 0.48888889 0.13333333 0.24444444]
#  [0.08888889 0.17777778 0.48888889 0.24444444]
#  [0.05555556 0.26666667 0.17777778 0.5       ]]
