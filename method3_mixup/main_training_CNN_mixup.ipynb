# %%
import tensorflow.compat.v1 as tf

tf.config.set_soft_device_placement(True)
# tf.debugging.set_log_device_placement(True)
# from sklearn.metrics import confusion_matrix
import numpy as np
# from scipy.io import loadmat
import os
# from functools import reduce
# from scipy import signal
import pandas as pd
# from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow import keras as K
from tensorflow.keras.layers import Add, Dense, Activation, Flatten, concatenate, Input, Dropout, LSTM, Conv2D, MaxPooling2D, Conv1D, MaxPooling1D, BatchNormalization, PReLU, ELU, ReLU
from tensorflow.keras.models import Sequential, Model, load_model
import matplotlib.pyplot as plt
# import datetime
# get_ipython().run_line_magic('load_ext', 'tensorboard')
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# get_ipython().run_line_magic('matplotlib', 'inline')
# from collections import Counter 
np_load_old = np.load
# from tensorflow.keras.utils import plot_model
from tensorflow.keras.initializers import glorot_uniform
# modify the default parameters of np.load
np.load = lambda *a,**k: np_load_old(*a, allow_pickle=True, **k)
np.random.seed(42)
tf.set_random_seed(42)
from sklearn.metrics import classification_report
import argparse
import h5py

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import itertools

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.figure(figsize=(15,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=36)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=30)
    plt.yticks(tick_marks, classes, fontsize=30)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black", fontsize=28)

    plt.tight_layout()
    plt.ylabel('True label', fontsize=30)
    plt.xlabel('Predicted label', fontsize=30)

# %% [markdown]
# ## Load in data

# %%
# load new train, validation, and test datasets
# load new train, validation, and test datasets
loadPath = '/home/sz4544/EEG-motor-imagery-main/project/'
os.makedirs(os.path.join(loadPath, "models"), exist_ok=True)
bestModel = '/home/sz4544/EEG-motor-imagery-main/project/models/mixup_tr1800-val360ts_2CNN.keras'

f_train = h5py.File(os.path.join(loadPath, "train1800_raw_EEG.h5"), "r")
tr_data = f_train['data'][:]
ytr = f_train['tasks'][:]
tr_subjects = f_train['subjects'][:]

f_valid = h5py.File(os.path.join(loadPath, "valid360_raw_EEG.h5"), "r")
val_data = f_valid['data'][:]
yval = f_valid['tasks'][:]
val_subjects = f_valid['subjects'][:]

f_test = h5py.File(os.path.join(loadPath, "test360_raw_EEG.h5"), "r")
ts_data = f_test['data'][:]
yts = f_test['tasks'][:]
ts_subjects = f_test['subjects'][:]

# %% [markdown]
# ## Normalization

# %%
# flatten and reshape data
xtr_s_flattened = np.squeeze(tr_data).ravel().reshape((-1, 64))
xval_s_flattened = np.squeeze(val_data).ravel().reshape((-1, 64))
xts_s_flattened = np.squeeze(ts_data).ravel().reshape((-1, 64))
print(xtr_s_flattened.shape)
print(xval_s_flattened.shape)
print(xts_s_flattened.shape)

# normalize data
scaler = StandardScaler()
Ztr_temp = scaler.fit_transform(xtr_s_flattened)
Zval_temp = scaler.transform(xval_s_flattened)
Zts_temp = scaler.transform(xts_s_flattened)

# flatten and reshape data back
Ztr = np.squeeze(Ztr_temp).ravel().reshape((-1, 640, 64))
Zval = np.squeeze(Zval_temp).ravel().reshape((-1, 640, 64))
Zts = np.squeeze(Zts_temp).ravel().reshape((-1, 640, 64))
print(Ztr.shape)
print(Zval.shape)
print(Zts.shape)
# Out:
# (1152000, 64)
# (230400, 64)
# (230400, 64)
# (1800, 640, 64)
# (360, 640, 64)
# (360, 640, 64)

# %%
x_train = Ztr[..., np.newaxis].astype(np.float32)
x_valid = Zval[..., np.newaxis].astype(np.float32)
x_test = Zts[..., np.newaxis].astype(np.float32)
y_train = pd.get_dummies(ytr).values.astype(np.float32)
y_valid = pd.get_dummies(yval).values.astype(np.float32)
y_test = pd.get_dummies(yts).values.astype(np.float32)
# Mixup augmentation: only applied to training data
alpha = 0.2

n_train = x_train.shape[0]
indices = np.random.permutation(n_train)
lam = np.random.beta(alpha, alpha, size=n_train)

x_train_perm = x_train[indices]
y_train_perm = y_train[indices]

lam_x = lam.reshape(-1, 1, 1, 1)
lam_y = lam.reshape(-1, 1)

x_train_aug = lam_x * x_train + (1 - lam_x) * x_train_perm
y_train_aug = lam_y * y_train + (1 - lam_y) * y_train_perm

print("x_train shape:", x_train.shape)
print("x_train_aug shape:", x_train_aug.shape)
print("y_train shape:", y_train.shape)
print("y_train_aug shape:", y_train_aug.shape)
print("alpha:", alpha)
# Out:
# x_train shape: (1800, 640, 64, 1)
# x_train_aug shape: (1800, 640, 64, 1)
# y_train shape: (1800, 4)
# y_train_aug shape: (1800, 4)
# alpha: 0.2

# %% [markdown]
# ## Model architecture

# %%
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
with strategy.scope():
    nodes = 640
    inputs = Input(shape=(nodes, 64, 1))

    conv1 = Conv2D(8, (15,9), strides=(2,1), kernel_initializer = glorot_uniform(seed=42))(inputs)
    batch1 = BatchNormalization()(conv1)
    prelu1 = PReLU()(batch1)
    maxpool1 = MaxPooling2D((2,2))(prelu1)
    conv2 = Conv2D(16, (15,9), strides=(2,1), kernel_initializer = glorot_uniform(seed=42))(maxpool1)
    batch2 = BatchNormalization()(conv2)
    prelu2 = PReLU()(batch2)
    # maxpool2 = MaxPooling2D((5,1))(prelu2)

    flat = Flatten()(prelu2)
    dense1 = Dense(16, activation='sigmoid', kernel_initializer = glorot_uniform(seed=42))(flat)
    drop1 = Dropout(0.2)(dense1)
    predictions = Dense(4, activation='softmax', kernel_initializer = glorot_uniform(seed=42))(drop1)
    model = Model(inputs=inputs,outputs=predictions)
print(model.summary())
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 640, 64, 1)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 313, 56, 8)     │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 313, 56, 8)     │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ p_re_lu_2 (PReLU)               │ (None, 313, 56, 8)     │       140,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 156, 28, 8)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 71, 20, 16)     │        17,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 71, 20, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ p_re_lu_3 (PReLU)               │ (None, 71, 20, 16)     │        22,720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 22720)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │       363,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │            68 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 545,028 (2.08 MB)
#  Trainable params: 544,980 (2.08 MB)
#  Non-trainable params: 48 (192.00 B)
# None

# %%
with strategy.scope():
    opt_adam = K.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
    model.compile(loss='categorical_crossentropy', optimizer=opt_adam, metrics=['categorical_accuracy'])

es = EarlyStopping(monitor='val_categorical_accuracy', mode='max', verbose=1, patience=30)
mc = ModelCheckpoint(bestModel, monitor='val_categorical_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
history = model.fit(x=x_train_aug, y=y_train_aug, epochs=300, shuffle=True,
                    verbose=1, validation_data = (x_valid, y_valid), callbacks=[es, mc])
# Out:
# Epoch 1/300
# INFO:tensorflow:Collective all_reduce tensors: 14 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.2737 - loss: 1.4137
# Epoch 1: val_categorical_accuracy improved from None to 0.26389, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/mixup_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - categorical_accuracy: 0.3072 - loss: 1.3805 - val_categorical_accuracy: 0.2639 - val_loss: 1.3743
# Epoch 2/300
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.4132 - loss: 1.2882
# Epoch 2: val_categorical_accuracy improved from 0.26389 to 0.31944, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/mixup_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - categorical_accuracy: 0.4094 - loss: 1.2848 - val_categorical_accuracy: 0.3194 - val_loss: 1.3634
# Epoch 3/300
# 53/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.5177 - loss: 1.1809
# Epoch 3: val_categorical_accuracy improved from 0.31944 to 0.35556, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/mixup_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - categorical_accuracy: 0.5139 - loss: 1.1841 - val_categorical_accuracy: 0.3556 - val_loss: 1.3552
# Epoch 4/300
# 54/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.5784 - loss: 1.0911
# Epoch 4: val_categorical_accuracy improved from 0.35556 to 0.40000, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/mixup_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.5939 - loss: 1.0851 - val_categorical_accuracy: 0.4000 - val_loss: 1.3173
# Epoch 5/300
# 55/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.6698 - loss: 1.0112
# Epoch 5: val_categorical_accuracy improved from 0.40000 to 0.41389, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/mixup_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.6589 - loss: 1.0072 - val_categorical_accuracy: 0.4139 - val_loss: 1.3043
# Epoch 6/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.7126 - loss: 0.9244
# Epoch 6: val_categorical_accuracy improved from 0.41389 to 0.42778, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/mixup_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - categorical_accuracy: 0.7172 - loss: 0.9191 - val_categorical_accuracy: 0.4278 - val_loss: 1.2858
# Epoch 7/300
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.7526 - loss: 0.8688
# Epoch 7: val_categorical_accuracy improved from 0.42778 to 0.44167, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/mixup_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.7511 - loss: 0.8691 - val_categorical_accuracy: 0.4417 - val_loss: 1.2832
# Epoch 8/300
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.7905 - loss: 0.8084
# Epoch 8: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.7800 - loss: 0.8158 - val_categorical_accuracy: 0.4278 - val_loss: 1.3021
# Epoch 9/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.8148 - loss: 0.7599
# Epoch 9: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.8122 - loss: 0.7634 - val_categorical_accuracy: 0.4306 - val_loss: 1.2978
# Epoch 10/300
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.8486 - loss: 0.7242
# Epoch 10: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - categorical_accuracy: 0.8422 - loss: 0.7237 - val_categorical_accuracy: 0.4361 - val_loss: 1.3116
# Epoch 11/300
# 54/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.8585 - loss: 0.6961
# Epoch 11: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - categorical_accuracy: 0.8494 - loss: 0.6917 - val_categorical_accuracy: 0.4306 - val_loss: 1.3188
# Epoch 12/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.8804 - loss: 0.6531
# Epoch 12: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - categorical_accuracy: 0.8789 - loss: 0.6580 - val_categorical_accuracy: 0.4250 - val_loss: 1.3108
# Epoch 13/300
# 55/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.8976 - loss: 0.6185
# Epoch 13: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - categorical_accuracy: 0.8994 - loss: 0.6160 - val_categorical_accuracy: 0.4194 - val_loss: 1.3245
# Epoch 14/300
# 53/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9000 - loss: 0.6058
# Epoch 14: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.8956 - loss: 0.6004 - val_categorical_accuracy: 0.4250 - val_loss: 1.3327
# Epoch 15/300
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9165 - loss: 0.5693
# Epoch 15: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.9139 - loss: 0.5702 - val_categorical_accuracy: 0.4361 - val_loss: 1.3271
# Epoch 16/300
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9267 - loss: 0.5517
# Epoch 16: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.9239 - loss: 0.5417 - val_categorical_accuracy: 0.4250 - val_loss: 1.3342
# Epoch 17/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9370 - loss: 0.5346
# Epoch 17: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.9356 - loss: 0.5286 - val_categorical_accuracy: 0.4139 - val_loss: 1.3410
# Epoch 18/300
# 53/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.9433 - loss: 0.5069
# Epoch 18: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.9406 - loss: 0.5119 - val_categorical_accuracy: 0.4361 - val_loss: 1.3463
# Epoch 19/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9485 - loss: 0.4967
# Epoch 19: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.9444 - loss: 0.4917 - val_categorical_accuracy: 0.4194 - val_loss: 1.3532
# Epoch 20/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9428 - loss: 0.4790
# Epoch 20: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.9450 - loss: 0.4786 - val_categorical_accuracy: 0.4306 - val_loss: 1.3595
# Epoch 21/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9479 - loss: 0.4682
# Epoch 21: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.9533 - loss: 0.4633 - val_categorical_accuracy: 0.4083 - val_loss: 1.3665
# Epoch 22/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9585 - loss: 0.4534
# Epoch 22: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.9544 - loss: 0.4504 - val_categorical_accuracy: 0.4222 - val_loss: 1.3908
# Epoch 23/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9559 - loss: 0.4423
# Epoch 23: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.9583 - loss: 0.4383 - val_categorical_accuracy: 0.4167 - val_loss: 1.3870
# Epoch 24/300
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9652 - loss: 0.4269
# Epoch 24: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.9617 - loss: 0.4247 - val_categorical_accuracy: 0.4028 - val_loss: 1.3805
# Epoch 25/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9575 - loss: 0.4300
# Epoch 25: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.9622 - loss: 0.4250 - val_categorical_accuracy: 0.3861 - val_loss: 1.3930
# Epoch 26/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9612 - loss: 0.4196
# Epoch 26: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.9567 - loss: 0.4219 - val_categorical_accuracy: 0.3889 - val_loss: 1.3936
# Epoch 27/300
# 54/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.9677 - loss: 0.4029
# Epoch 27: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.9667 - loss: 0.4000 - val_categorical_accuracy: 0.4000 - val_loss: 1.4096
# Epoch 28/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9670 - loss: 0.3976
# Epoch 28: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.9644 - loss: 0.4015 - val_categorical_accuracy: 0.3972 - val_loss: 1.4068
# Epoch 29/300
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9645 - loss: 0.3904
# Epoch 29: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - categorical_accuracy: 0.9683 - loss: 0.3868 - val_categorical_accuracy: 0.3889 - val_loss: 1.4229
# Epoch 30/300
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9614 - loss: 0.3829
# Epoch 30: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.9606 - loss: 0.3830 - val_categorical_accuracy: 0.3972 - val_loss: 1.4184
# Epoch 31/300
# 53/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.9667 - loss: 0.3649
# Epoch 31: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.9694 - loss: 0.3686 - val_categorical_accuracy: 0.3889 - val_loss: 1.4461
# Epoch 32/300
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9617 - loss: 0.3631
# Epoch 32: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.9672 - loss: 0.3674 - val_categorical_accuracy: 0.3972 - val_loss: 1.4430
# Epoch 33/300
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.9653 - loss: 0.3686
# Epoch 33: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.9633 - loss: 0.3687 - val_categorical_accuracy: 0.3889 - val_loss: 1.4567
# Epoch 34/300
# 54/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.9680 - loss: 0.3636
# Epoch 34: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - categorical_accuracy: 0.9661 - loss: 0.3599 - val_categorical_accuracy: 0.3778 - val_loss: 1.4647
# Epoch 35/300
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9778 - loss: 0.3584
# Epoch 35: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.9722 - loss: 0.3591 - val_categorical_accuracy: 0.3917 - val_loss: 1.4766
# Epoch 36/300
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.9597 - loss: 0.3522
# Epoch 36: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.9606 - loss: 0.3531 - val_categorical_accuracy: 0.3806 - val_loss: 1.4844
# Epoch 37/300
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.9674 - loss: 0.3545
# Epoch 37: val_categorical_accuracy did not improve from 0.44167
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - categorical_accuracy: 0.9700 - loss: 0.3495 - val_categorical_accuracy: 0.3722 - val_loss: 1.4855
# Epoch 37: early stopping

# %% [markdown]
# ## Model testing

# %%
best_model = tf.keras.models.load_model(bestModel)
yhat = np.argmax(best_model.predict(x_test), axis=1)
ytrue = np.argmax(y_test, axis=1)
print('test acc: {:.2f}%'.format(np.sum(yhat == ytrue) / yts.shape[0] * 100))
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# test acc: 41.67%

# %%
target_names = ['open one hand', 'imagine open one hand', 'open both hands/feet', 'imagine open both hands/feet']
print(classification_report(ytrue, yhat, target_names=target_names, digits=4))
# Out:
#                               precision    recall  f1-score   support
#
#                open one hand     0.4706    0.1778    0.2581        90
#        imagine open one hand     0.3481    0.5222    0.4178        90
#         open both hands/feet     0.4592    0.5000    0.4787        90
# imagine open both hands/feet     0.4516    0.4667    0.4590        90
#
#                     accuracy                         0.4167       360
#                    macro avg     0.4324    0.4167    0.4034       360
#                 weighted avg     0.4324    0.4167    0.4034       360

# %%
cm = confusion_matrix(ytrue, yhat)
cm
# Out:
# array([[16, 41, 23, 10],
#        [ 9, 47, 11, 23],
#        [ 6, 21, 45, 18],
#        [ 3, 26, 19, 42]])

# %%
plot_confusion_matrix(cm, ['Task1', 'Task2', 'Task3', 'Task4'], normalize=True, title='Confusion matrix', cmap=plt.cm.Greys)
# Out:
# Normalized confusion matrix
# [[0.17777778 0.45555556 0.25555556 0.11111111]
#  [0.1        0.52222222 0.12222222 0.25555556]
#  [0.06666667 0.23333333 0.5        0.2       ]
#  [0.03333333 0.28888889 0.21111111 0.46666667]]
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。
