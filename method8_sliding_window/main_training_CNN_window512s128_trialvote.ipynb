# %%
import tensorflow.compat.v1 as tf

tf.config.set_soft_device_placement(True)
# tf.debugging.set_log_device_placement(True)
# from sklearn.metrics import confusion_matrix
import numpy as np
# from scipy.io import loadmat
import os
# from functools import reduce
# from scipy import signal
import pandas as pd
# from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow import keras as K
from tensorflow.keras.layers import Add, Dense, Activation, Flatten, concatenate, Input, Dropout, LSTM, Conv2D, MaxPooling2D, Conv1D, MaxPooling1D, BatchNormalization, PReLU, ELU, ReLU
from tensorflow.keras.models import Sequential, Model, load_model
import matplotlib.pyplot as plt
# import datetime
# get_ipython().run_line_magic('load_ext', 'tensorboard')
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# get_ipython().run_line_magic('matplotlib', 'inline')
# from collections import Counter 
np_load_old = np.load
# from tensorflow.keras.utils import plot_model
from tensorflow.keras.initializers import glorot_uniform
# modify the default parameters of np.load
np.load = lambda *a,**k: np_load_old(*a, allow_pickle=True, **k)
np.random.seed(42)
tf.set_random_seed(42)
from sklearn.metrics import classification_report
import argparse
import h5py

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import itertools
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774213766.966430  101353 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.figure(figsize=(15,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=36)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=30)
    plt.yticks(tick_marks, classes, fontsize=30)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black", fontsize=28)

    plt.tight_layout()
    plt.ylabel('True label', fontsize=30)
    plt.xlabel('Predicted label', fontsize=30)

# %% [markdown]
# ## Load in data

# %%
# load windowed-train dataset + sliding-window validation/test datasets for trial vote
loadPath = '/home/sz4544/EEG-motor-imagery-main/project/'
os.makedirs(os.path.join(loadPath, "models"), exist_ok=True)

bestModel = '/home/sz4544/EEG-motor-imagery-main/project/models/baseline_tr1800_window512s128_trialvote_2CNN.keras'

f_train = h5py.File(os.path.join(loadPath, "train1800_window512s128_raw_EEG.h5"), "r")
tr_data = f_train['data'][:]
ytr = f_train['tasks'][:]
tr_subjects = f_train['subjects'][:]
tr_trial_ids = f_train['trial_ids'][:]
f_train.close()

f_valid = h5py.File(os.path.join(loadPath, "valid360_window512s128_trialvote_raw_EEG.h5"), "r")
val_data = f_valid['data'][:]
yval = f_valid['tasks'][:]
val_subjects = f_valid['subjects'][:]
val_trial_ids = f_valid['trial_ids'][:]
f_valid.close()

f_test = h5py.File(os.path.join(loadPath, "test360_window512s128_trialvote_raw_EEG.h5"), "r")
ts_data = f_test['data'][:]
yts = f_test['tasks'][:]
ts_subjects = f_test['subjects'][:]
ts_trial_ids = f_test['trial_ids'][:]
f_test.close()

print("train:", tr_data.shape, ytr.shape)
print("valid:", val_data.shape, yval.shape)
print("test:", ts_data.shape, yts.shape)

print("train labels:", np.unique(ytr, return_counts=True))
print("valid labels:", np.unique(yval, return_counts=True))
print("test labels:", np.unique(yts, return_counts=True))

print("unique valid trials:", len(np.unique(val_trial_ids)))
print("unique test trials:", len(np.unique(ts_trial_ids)))
# Out:
# train: (3600, 512, 64) (3600,)
# valid: (720, 512, 64) (720,)
# test: (720, 512, 64) (720,)
# train labels: (array([1., 2., 3., 4.]), array([900, 900, 900, 900]))
# valid labels: (array([1., 2., 3., 4.]), array([180, 180, 180, 180]))
# test labels: (array([1., 2., 3., 4.]), array([180, 180, 180, 180]))
# unique valid trials: 360
# unique test trials: 360

# %% [markdown]
# ## Normalization

# %%
# flatten and reshape data
xtr_s_flattened = np.squeeze(tr_data).ravel().reshape((-1, 64))
xval_s_flattened = np.squeeze(val_data).ravel().reshape((-1, 64))
xts_s_flattened = np.squeeze(ts_data).ravel().reshape((-1, 64))
print(xtr_s_flattened.shape)
print(xval_s_flattened.shape)
print(xts_s_flattened.shape)

# normalize data
scaler = StandardScaler()
Ztr_temp = scaler.fit_transform(xtr_s_flattened)
Zval_temp = scaler.transform(xval_s_flattened)
Zts_temp = scaler.transform(xts_s_flattened)

# reshape back
Ztr = np.squeeze(Ztr_temp).ravel().reshape((-1, 512, 64))
Zval = np.squeeze(Zval_temp).ravel().reshape((-1, 512, 64))
Zts = np.squeeze(Zts_temp).ravel().reshape((-1, 512, 64))

print("Ztr:", Ztr.shape)
print("Zval:", Zval.shape)
print("Zts:", Zts.shape)
# Out:
# (1843200, 64)
# (368640, 64)
# (368640, 64)
# Ztr: (3600, 512, 64)
# Zval: (720, 512, 64)
# Zts: (720, 512, 64)

# %%
# remap labels to 0,1,2,3 if needed
ytr = ytr.astype(np.int64)
yval = yval.astype(np.int64)
yts = yts.astype(np.int64)

if np.array_equal(np.unique(ytr), np.array([1, 2, 3, 4])):
    ytr = ytr - 1
if np.array_equal(np.unique(yval), np.array([1, 2, 3, 4])):
    yval = yval - 1
if np.array_equal(np.unique(yts), np.array([1, 2, 3, 4])):
    yts = yts - 1

x_train = Ztr[..., np.newaxis]
x_valid = Zval[..., np.newaxis]
x_test = Zts[..., np.newaxis]

y_train = pd.get_dummies(ytr).values.astype(np.float32)
y_valid = pd.get_dummies(yval).values.astype(np.float32)
y_test = pd.get_dummies(yts).values.astype(np.float32)

print("x_train:", x_train.shape, x_train.dtype)
print("x_valid:", x_valid.shape, x_valid.dtype)
print("x_test:", x_test.shape, x_test.dtype)

print("y_train:", y_train.shape, y_train.dtype)
print("y_valid:", y_valid.shape, y_valid.dtype)
print("y_test:", y_test.shape, y_test.dtype)
# Out:
# x_train: (3600, 512, 64, 1) float64
# x_valid: (720, 512, 64, 1) float64
# x_test: (720, 512, 64, 1) float64
# y_train: (3600, 4) float32
# y_valid: (720, 4) float32
# y_test: (720, 4) float32

# %% [markdown]
# ## Model architecture

# %%
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# I0000 00:00:1774213770.334899  101353 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22272 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:41:00.0, compute capability: 8.9
# I0000 00:00:1774213770.335423  101353 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 22253 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:61:00.0, compute capability: 8.9
# Number of devices: 2

# %%
with strategy.scope():
    nodes = 512
    inputs = Input(shape=(nodes, 64, 1))

    conv1 = Conv2D(8, (15,9), strides=(2,1), kernel_initializer = glorot_uniform(seed=42))(inputs)
    batch1 = BatchNormalization()(conv1)
    prelu1 = PReLU()(batch1)
    maxpool1 = MaxPooling2D((2,2))(prelu1)
    conv2 = Conv2D(16, (15,9), strides=(2,1), kernel_initializer = glorot_uniform(seed=42))(maxpool1)
    batch2 = BatchNormalization()(conv2)
    prelu2 = PReLU()(batch2)
    # maxpool2 = MaxPooling2D((5,1))(prelu2)

    flat = Flatten()(prelu2)
    dense1 = Dense(16, activation='sigmoid', kernel_initializer = glorot_uniform(seed=42))(flat)
    drop1 = Dropout(0.2)(dense1)
    predictions = Dense(4, activation='softmax', kernel_initializer = glorot_uniform(seed=42))(drop1)
    model = Model(inputs=inputs,outputs=predictions)
print(model.summary())
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 512, 64, 1)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 249, 56, 8)     │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 249, 56, 8)     │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ p_re_lu (PReLU)                 │ (None, 249, 56, 8)     │       111,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 124, 28, 8)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 55, 20, 16)     │        17,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 55, 20, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ p_re_lu_1 (PReLU)               │ (None, 55, 20, 16)     │        17,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 17600)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │       281,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            68 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 429,316 (1.64 MB)
#  Trainable params: 429,268 (1.64 MB)
#  Non-trainable params: 48 (192.00 B)
# None

# %%
with strategy.scope():
    opt_adam = K.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
    model.compile(loss='categorical_crossentropy', optimizer=opt_adam, metrics=['categorical_accuracy'])

es = EarlyStopping(monitor='val_categorical_accuracy', mode='max', verbose=1, patience=30)
mc = ModelCheckpoint(bestModel, monitor='val_categorical_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
history = model.fit(x=x_train, y=y_train, epochs=300, shuffle=True,
                    verbose=1, validation_data = (x_valid, y_valid), callbacks=[es, mc])
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1/300
# I0000 00:00:1774213772.396997  101353 generator_dataset_op.cc:213] Memory patch applied: M_TRIM_THRESHOLD=128 kb was set.
# INFO:tensorflow:Collective all_reduce tensors: 14 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# I0000 00:00:1774213773.664164  101578 cuda_dnn.cc:461] Loaded cuDNN version 91002
# I0000 00:00:1774213773.687490  101577 cuda_dnn.cc:461] Loaded cuDNN version 91002
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.2677 - loss: 1.4177INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
#
# Epoch 1: val_categorical_accuracy improved from None to 0.32639, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/baseline_tr1800_window512s128_trialvote_2CNN.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - categorical_accuracy: 0.2944 - loss: 1.3846 - val_categorical_accuracy: 0.3264 - val_loss: 1.3609
# Epoch 2/300
# 109/113 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.3497 - loss: 1.3241
# Epoch 2: val_categorical_accuracy improved from 0.32639 to 0.33333, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/baseline_tr1800_window512s128_trialvote_2CNN.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.3608 - loss: 1.3167 - val_categorical_accuracy: 0.3333 - val_loss: 1.3384
# Epoch 3/300
# 110/113 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.4215 - loss: 1.2738
# Epoch 3: val_categorical_accuracy improved from 0.33333 to 0.37639, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/baseline_tr1800_window512s128_trialvote_2CNN.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.4164 - loss: 1.2627 - val_categorical_accuracy: 0.3764 - val_loss: 1.3050
# Epoch 4/300
# 110/113 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.4908 - loss: 1.1869
# Epoch 4: val_categorical_accuracy improved from 0.37639 to 0.38333, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/baseline_tr1800_window512s128_trialvote_2CNN.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.4883 - loss: 1.1871 - val_categorical_accuracy: 0.3833 - val_loss: 1.2895
# Epoch 5/300
# 111/113 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5248 - loss: 1.1273
# Epoch 5: val_categorical_accuracy improved from 0.38333 to 0.39444, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/baseline_tr1800_window512s128_trialvote_2CNN.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - categorical_accuracy: 0.5256 - loss: 1.1236 - val_categorical_accuracy: 0.3944 - val_loss: 1.2798
# Epoch 6/300
# 109/113 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.5776 - loss: 1.0683
# Epoch 6: val_categorical_accuracy improved from 0.39444 to 0.42222, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/baseline_tr1800_window512s128_trialvote_2CNN.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.5767 - loss: 1.0584 - val_categorical_accuracy: 0.4222 - val_loss: 1.2714
# Epoch 7/300
# 110/113 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.6129 - loss: 1.0063
# Epoch 7: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.6175 - loss: 1.0006 - val_categorical_accuracy: 0.4153 - val_loss: 1.2727
# Epoch 8/300
# 108/113 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.6698 - loss: 0.9494
# Epoch 8: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.6631 - loss: 0.9456 - val_categorical_accuracy: 0.4194 - val_loss: 1.2672
# Epoch 9/300
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6938 - loss: 0.8923
# Epoch 9: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - categorical_accuracy: 0.6961 - loss: 0.8834 - val_categorical_accuracy: 0.4153 - val_loss: 1.2694
# Epoch 10/300
# 108/113 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.7226 - loss: 0.8542
# Epoch 10: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.7247 - loss: 0.8473 - val_categorical_accuracy: 0.4167 - val_loss: 1.2756
# Epoch 11/300
# 111/113 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.7552 - loss: 0.7964
# Epoch 11: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - categorical_accuracy: 0.7608 - loss: 0.7875 - val_categorical_accuracy: 0.4097 - val_loss: 1.2834
# Epoch 12/300
# 107/113 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.7800 - loss: 0.7476
# Epoch 12: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.7861 - loss: 0.7429 - val_categorical_accuracy: 0.4028 - val_loss: 1.2922
# Epoch 13/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.8064 - loss: 0.7126
# Epoch 13: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.8086 - loss: 0.7040 - val_categorical_accuracy: 0.3903 - val_loss: 1.3025
# Epoch 14/300
# 108/113 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.8313 - loss: 0.6636
# Epoch 14: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - categorical_accuracy: 0.8356 - loss: 0.6599 - val_categorical_accuracy: 0.3972 - val_loss: 1.3009
# Epoch 15/300
# 108/113 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.8560 - loss: 0.6197
# Epoch 15: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - categorical_accuracy: 0.8597 - loss: 0.6124 - val_categorical_accuracy: 0.3958 - val_loss: 1.3185
# Epoch 16/300
# 108/113 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.8723 - loss: 0.5830
# Epoch 16: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.8683 - loss: 0.5832 - val_categorical_accuracy: 0.3944 - val_loss: 1.3191
# Epoch 17/300
# 109/113 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.8755 - loss: 0.5628
# Epoch 17: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - categorical_accuracy: 0.8931 - loss: 0.5465 - val_categorical_accuracy: 0.3917 - val_loss: 1.3333
# Epoch 18/300
# 110/113 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.8870 - loss: 0.5266
# Epoch 18: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.8947 - loss: 0.5165 - val_categorical_accuracy: 0.3792 - val_loss: 1.3516
# Epoch 19/300
# 108/113 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.9059 - loss: 0.4983
# Epoch 19: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - categorical_accuracy: 0.9119 - loss: 0.4846 - val_categorical_accuracy: 0.3903 - val_loss: 1.3472
# Epoch 20/300
# 108/113 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.9080 - loss: 0.4663
# Epoch 20: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - categorical_accuracy: 0.9197 - loss: 0.4493 - val_categorical_accuracy: 0.3903 - val_loss: 1.3593
# Epoch 21/300
# 110/113 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.9244 - loss: 0.4295
# Epoch 21: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.9289 - loss: 0.4216 - val_categorical_accuracy: 0.3903 - val_loss: 1.3757
# Epoch 22/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9370 - loss: 0.4026
# Epoch 22: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.9425 - loss: 0.3959 - val_categorical_accuracy: 0.3819 - val_loss: 1.3952
# Epoch 23/300
# 109/113 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.9469 - loss: 0.3812
# Epoch 23: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - categorical_accuracy: 0.9514 - loss: 0.3732 - val_categorical_accuracy: 0.3833 - val_loss: 1.3977
# Epoch 24/300
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.9441 - loss: 0.3630
# Epoch 24: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.9522 - loss: 0.3525 - val_categorical_accuracy: 0.3833 - val_loss: 1.4166
# Epoch 25/300
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9549 - loss: 0.3439
# Epoch 25: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.9575 - loss: 0.3304 - val_categorical_accuracy: 0.3861 - val_loss: 1.4277
# Epoch 26/300
# 109/113 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.9547 - loss: 0.3360
# Epoch 26: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - categorical_accuracy: 0.9614 - loss: 0.3212 - val_categorical_accuracy: 0.3861 - val_loss: 1.4336
# Epoch 27/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.9688 - loss: 0.3031
# Epoch 27: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.9692 - loss: 0.2942 - val_categorical_accuracy: 0.3889 - val_loss: 1.4479
# Epoch 28/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9686 - loss: 0.2828
# Epoch 28: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.9725 - loss: 0.2732 - val_categorical_accuracy: 0.3875 - val_loss: 1.4650
# Epoch 29/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9728 - loss: 0.2661
# Epoch 29: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.9764 - loss: 0.2584 - val_categorical_accuracy: 0.3847 - val_loss: 1.4734
# Epoch 30/300
# 111/113 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9777 - loss: 0.2550
# Epoch 30: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.9767 - loss: 0.2492 - val_categorical_accuracy: 0.4056 - val_loss: 1.4913
# Epoch 31/300
# 111/113 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.9823 - loss: 0.2338
# Epoch 31: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.9808 - loss: 0.2310 - val_categorical_accuracy: 0.3889 - val_loss: 1.4943
# Epoch 32/300
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9795 - loss: 0.2334
# Epoch 32: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - categorical_accuracy: 0.9775 - loss: 0.2282 - val_categorical_accuracy: 0.3861 - val_loss: 1.5137
# Epoch 33/300
# 111/113 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.9839 - loss: 0.2160
# Epoch 33: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - categorical_accuracy: 0.9844 - loss: 0.2095 - val_categorical_accuracy: 0.3792 - val_loss: 1.5299
# Epoch 34/300
# 110/113 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - categorical_accuracy: 0.9865 - loss: 0.2001
# Epoch 34: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - categorical_accuracy: 0.9886 - loss: 0.1956 - val_categorical_accuracy: 0.3833 - val_loss: 1.5416
# Epoch 35/300
# 111/113 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - categorical_accuracy: 0.9863 - loss: 0.1895
# Epoch 35: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - categorical_accuracy: 0.9867 - loss: 0.1874 - val_categorical_accuracy: 0.3847 - val_loss: 1.5502
# Epoch 36/300
# 112/113 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.9895 - loss: 0.1818
# Epoch 36: val_categorical_accuracy did not improve from 0.42222
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - categorical_accuracy: 0.9886 - loss: 0.1781 - val_categorical_accuracy: 0.3792 - val_loss: 1.5678
# Epoch 36: early stopping

# %% [markdown]
# ## Model testing

# %%
best_model = tf.keras.models.load_model(bestModel)

# window-level prediction
test_probs = best_model.predict(x_test)

trial_ids = ts_trial_ids
labels = yts

unique_trials = np.unique(trial_ids)

trial_probs = []
trial_true = []

for tid in unique_trials:
    idx = np.where(trial_ids == tid)[0]

    avg_prob = np.mean(test_probs[idx], axis=0)

    trial_probs.append(avg_prob)
    trial_true.append(labels[idx[0]])

trial_probs = np.array(trial_probs)
trial_true = np.array(trial_true)

yhat = np.argmax(trial_probs, axis=1)
ytrue = trial_true.copy()

if np.array_equal(np.unique(ytrue), np.array([1, 2, 3, 4])):
    ytrue = ytrue - 1

print("trial_probs:", trial_probs.shape)
print("ytrue:", ytrue.shape)

print('trial-level test acc: {:.2f}%'.format(
    np.sum(yhat == ytrue) / ytrue.shape[0] * 100
))
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# trial_probs: (360, 4)
# ytrue: (360,)
# trial-level test acc: 43.33%

# %%
target_names = [
    'open one hand',
    'imagine open one hand',
    'open both hands/feet',
    'imagine open both hands/feet'
]

print(classification_report(
    ytrue,
    yhat,
    target_names=target_names,
    digits=4
))
# Out:
#                               precision    recall  f1-score   support
#
#                open one hand     0.5088    0.3222    0.3946        90
#        imagine open one hand     0.3913    0.4000    0.3956        90
#         open both hands/feet     0.5400    0.3000    0.3857        90
# imagine open both hands/feet     0.3975    0.7111    0.5100        90
#
#                     accuracy                         0.4333       360
#                    macro avg     0.4594    0.4333    0.4215       360
#                 weighted avg     0.4594    0.4333    0.4215       360

# %%
cm = confusion_matrix(ytrue, yhat)
cm
# Out:
# array([[29, 26, 12, 23],
#        [11, 36,  5, 38],
#        [ 9, 18, 27, 36],
#        [ 8, 12,  6, 64]])

# %%
plot_confusion_matrix(
    cm,
    ['Task1', 'Task2', 'Task3', 'Task4'],
    normalize=True,
    title='Confusion matrix',
    cmap=plt.cm.Greys
)
# Out:
# Normalized confusion matrix
# [[0.32222222 0.28888889 0.13333333 0.25555556]
#  [0.12222222 0.4        0.05555556 0.42222222]
#  [0.1        0.2        0.3        0.4       ]
#  [0.08888889 0.13333333 0.06666667 0.71111111]]
