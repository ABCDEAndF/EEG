# %%
import tensorflow.compat.v1 as tf

tf.config.set_soft_device_placement(True)
# tf.debugging.set_log_device_placement(True)
# from sklearn.metrics import confusion_matrix
import numpy as np
# from scipy.io import loadmat
import os
# from functools import reduce
# from scipy import signal
import pandas as pd
# from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow import keras as K
from tensorflow.keras.layers import Add, Dense, Activation, Flatten, concatenate, Input, Dropout, LSTM, Conv2D, MaxPooling2D, Conv1D, MaxPooling1D, BatchNormalization, PReLU, ELU, ReLU
from tensorflow.keras.models import Sequential, Model, load_model
import matplotlib.pyplot as plt
# import datetime
# get_ipython().run_line_magic('load_ext', 'tensorboard')
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# get_ipython().run_line_magic('matplotlib', 'inline')
# from collections import Counter 
np_load_old = np.load
# from tensorflow.keras.utils import plot_model
from tensorflow.keras.initializers import glorot_uniform
# modify the default parameters of np.load
np.load = lambda *a,**k: np_load_old(*a, allow_pickle=True, **k)
np.random.seed(42)
tf.set_random_seed(42)
from sklearn.metrics import classification_report
import argparse
import h5py

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import itertools
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1773877343.958204 1701804 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.figure(figsize=(15,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=36)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=30)
    plt.yticks(tick_marks, classes, fontsize=30)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black", fontsize=28)

    plt.tight_layout()
    plt.ylabel('True label', fontsize=30)
    plt.xlabel('Predicted label', fontsize=30)

# %% [markdown]
# ## Load in data

# %%
# load new train, validation, and test datasets
# load new train, validation, and test datasets
loadPath = '/home/sz4544/EEG-motor-imagery-main/project/'
os.makedirs(os.path.join(loadPath, "models"), exist_ok=True)
bestModel = '/home/sz4544/EEG-motor-imagery-main/project/models/time_mask_tr1800-val360ts_2CNN.keras'

f_train = h5py.File(os.path.join(loadPath, "train1800_raw_EEG.h5"), "r")
tr_data = f_train['data'][:]
ytr = f_train['tasks'][:]
tr_subjects = f_train['subjects'][:]

f_valid = h5py.File(os.path.join(loadPath, "valid360_raw_EEG.h5"), "r")
val_data = f_valid['data'][:]
yval = f_valid['tasks'][:]
val_subjects = f_valid['subjects'][:]

f_test = h5py.File(os.path.join(loadPath, "test360_raw_EEG.h5"), "r")
ts_data = f_test['data'][:]
yts = f_test['tasks'][:]
ts_subjects = f_test['subjects'][:]

# %% [markdown]
# ## Normalization

# %%
# flatten and reshape data
xtr_s_flattened = np.squeeze(tr_data).ravel().reshape((-1, 64))
xval_s_flattened = np.squeeze(val_data).ravel().reshape((-1, 64))
xts_s_flattened = np.squeeze(ts_data).ravel().reshape((-1, 64))
print(xtr_s_flattened.shape)
print(xval_s_flattened.shape)
print(xts_s_flattened.shape)

# normalize data
scaler = StandardScaler()
Ztr_temp = scaler.fit_transform(xtr_s_flattened)
Zval_temp = scaler.transform(xval_s_flattened)
Zts_temp = scaler.transform(xts_s_flattened)

# flatten and reshape data back
Ztr = np.squeeze(Ztr_temp).ravel().reshape((-1, 640, 64))
Zval = np.squeeze(Zval_temp).ravel().reshape((-1, 640, 64))
Zts = np.squeeze(Zts_temp).ravel().reshape((-1, 640, 64))
print(Ztr.shape)
print(Zval.shape)
print(Zts.shape)
# Out:
# (1152000, 64)
# (230400, 64)
# (230400, 64)
# (1800, 640, 64)
# (360, 640, 64)
# (360, 640, 64)

# %%
x_train = Ztr[..., np.newaxis]
x_valid = Zval[..., np.newaxis]
x_test = Zts[..., np.newaxis]
y_train = pd.get_dummies(ytr).values
y_valid = pd.get_dummies(yval).values
y_test = pd.get_dummies(yts).values

# Time masking augmentation: only applied to training data
x_train_aug = x_train.copy()
y_train_aug = y_train.copy()

mask_len = 32   # number of time steps to mask
n_masks = 1     # number of masks per sample

for i in range(x_train_aug.shape[0]):
    for _ in range(n_masks):
        start = np.random.randint(0, x_train_aug.shape[1] - mask_len + 1)
        x_train_aug[i, start:start + mask_len, :, :] = 0.0

print("x_train shape:", x_train.shape)
print("x_train_aug shape:", x_train_aug.shape)
print("x_valid shape:", x_valid.shape)
print("x_test shape:", x_test.shape)
print("mask_len:", mask_len)
print("n_masks:", n_masks)
# Out:
# x_train shape: (1800, 640, 64, 1)
# x_train_aug shape: (1800, 640, 64, 1)
# x_valid shape: (360, 640, 64, 1)
# x_test shape: (360, 640, 64, 1)
# mask_len: 32
# n_masks: 1

# %% [markdown]
# ## Model architecture

# %%
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# Number of devices: 1
# I0000 00:00:1773877356.203928 1701804 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 902 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:41:00.0, compute capability: 8.9

# %%
with strategy.scope():
    nodes = 640
    inputs = Input(shape=(nodes, 64, 1))

    conv1 = Conv2D(8, (15,9), strides=(2,1), kernel_initializer = glorot_uniform(seed=42))(inputs)
    batch1 = BatchNormalization()(conv1)
    prelu1 = PReLU()(batch1)
    maxpool1 = MaxPooling2D((2,2))(prelu1)
    conv2 = Conv2D(16, (15,9), strides=(2,1), kernel_initializer = glorot_uniform(seed=42))(maxpool1)
    batch2 = BatchNormalization()(conv2)
    prelu2 = PReLU()(batch2)
    # maxpool2 = MaxPooling2D((5,1))(prelu2)

    flat = Flatten()(prelu2)
    dense1 = Dense(16, activation='sigmoid', kernel_initializer = glorot_uniform(seed=42))(flat)
    drop1 = Dropout(0.2)(dense1)
    predictions = Dense(4, activation='softmax', kernel_initializer = glorot_uniform(seed=42))(drop1)
    model = Model(inputs=inputs,outputs=predictions)
print(model.summary())
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 640, 64, 1)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 313, 56, 8)     │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 313, 56, 8)     │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ p_re_lu (PReLU)                 │ (None, 313, 56, 8)     │       140,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 156, 28, 8)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 71, 20, 16)     │        17,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 71, 20, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ p_re_lu_1 (PReLU)               │ (None, 71, 20, 16)     │        22,720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 22720)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │       363,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            68 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 545,028 (2.08 MB)
#  Trainable params: 544,980 (2.08 MB)
#  Non-trainable params: 48 (192.00 B)
# None

# %%
with strategy.scope():
    opt_adam = K.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
    model.compile(loss='categorical_crossentropy', optimizer=opt_adam, metrics=['categorical_accuracy'])

es = EarlyStopping(monitor='val_categorical_accuracy', mode='max', verbose=1, patience=30)
mc = ModelCheckpoint(bestModel, monitor='val_categorical_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
history = model.fit(x=x_train_aug, y=y_train_aug, epochs=300, shuffle=True,
                    verbose=1, validation_data = (x_valid, y_valid), callbacks=[es, mc])
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1/300
# I0000 00:00:1773877357.431144 1701804 generator_dataset_op.cc:213] Memory patch applied: M_TRIM_THRESHOLD=128 kb was set.
# I0000 00:00:1773877358.105439 1701959 cuda_dnn.cc:461] Loaded cuDNN version 90800
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.2828 - loss: 1.4102INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
#
# Epoch 1: val_categorical_accuracy improved from None to 0.28056, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/time_mask_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - categorical_accuracy: 0.2944 - loss: 1.3926 - val_categorical_accuracy: 0.2806 - val_loss: 1.3815
# Epoch 2/300
# 54/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.3957 - loss: 1.2926
# Epoch 2: val_categorical_accuracy improved from 0.28056 to 0.30278, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/time_mask_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - categorical_accuracy: 0.3778 - loss: 1.3040 - val_categorical_accuracy: 0.3028 - val_loss: 1.3738
# Epoch 3/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.4654 - loss: 1.2159
# Epoch 3: val_categorical_accuracy improved from 0.30278 to 0.33333, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/time_mask_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.4600 - loss: 1.2217 - val_categorical_accuracy: 0.3333 - val_loss: 1.3516
# Epoch 4/300
# 55/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5449 - loss: 1.1366
# Epoch 4: val_categorical_accuracy improved from 0.33333 to 0.34444, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/time_mask_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.5372 - loss: 1.1293 - val_categorical_accuracy: 0.3444 - val_loss: 1.3272
# Epoch 5/300
# 49/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5941 - loss: 1.0353
# Epoch 5: val_categorical_accuracy improved from 0.34444 to 0.39722, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/time_mask_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.6067 - loss: 1.0350 - val_categorical_accuracy: 0.3972 - val_loss: 1.2791
# Epoch 6/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6329 - loss: 0.9705
# Epoch 6: val_categorical_accuracy improved from 0.39722 to 0.40000, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/time_mask_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.6378 - loss: 0.9661 - val_categorical_accuracy: 0.4000 - val_loss: 1.2714
# Epoch 7/300
# 50/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.7040 - loss: 0.9148
# Epoch 7: val_categorical_accuracy improved from 0.40000 to 0.45556, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/time_mask_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.7006 - loss: 0.8998 - val_categorical_accuracy: 0.4556 - val_loss: 1.2413
# Epoch 8/300
# 54/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.7480 - loss: 0.8453
# Epoch 8: val_categorical_accuracy improved from 0.45556 to 0.47500, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/time_mask_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - categorical_accuracy: 0.7456 - loss: 0.8385 - val_categorical_accuracy: 0.4750 - val_loss: 1.2290
# Epoch 9/300
# 50/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7637 - loss: 0.7917
# Epoch 9: val_categorical_accuracy did not improve from 0.47500
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - categorical_accuracy: 0.7761 - loss: 0.7742 - val_categorical_accuracy: 0.4556 - val_loss: 1.2339
# Epoch 10/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.8076 - loss: 0.7405
# Epoch 10: val_categorical_accuracy did not improve from 0.47500
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.8011 - loss: 0.7326 - val_categorical_accuracy: 0.4500 - val_loss: 1.2240
# Epoch 11/300
# 50/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.8182 - loss: 0.7015
# Epoch 11: val_categorical_accuracy did not improve from 0.47500
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.8317 - loss: 0.6908 - val_categorical_accuracy: 0.4694 - val_loss: 1.2214
# Epoch 12/300
# 49/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.8380 - loss: 0.6594
# Epoch 12: val_categorical_accuracy did not improve from 0.47500
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.8456 - loss: 0.6555 - val_categorical_accuracy: 0.4667 - val_loss: 1.2228
# Epoch 13/300
# 50/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.8741 - loss: 0.6094
# Epoch 13: val_categorical_accuracy improved from 0.47500 to 0.48056, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/time_mask_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - categorical_accuracy: 0.8750 - loss: 0.6075 - val_categorical_accuracy: 0.4806 - val_loss: 1.2251
# Epoch 14/300
# 48/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.8835 - loss: 0.5882
# Epoch 14: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.8939 - loss: 0.5738 - val_categorical_accuracy: 0.4500 - val_loss: 1.2285
# Epoch 15/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9203 - loss: 0.5415
# Epoch 15: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9133 - loss: 0.5424 - val_categorical_accuracy: 0.4806 - val_loss: 1.2309
# Epoch 16/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9183 - loss: 0.5177
# Epoch 16: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9239 - loss: 0.5121 - val_categorical_accuracy: 0.4778 - val_loss: 1.2493
# Epoch 17/300
# 55/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9345 - loss: 0.4838
# Epoch 17: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9272 - loss: 0.4803 - val_categorical_accuracy: 0.4694 - val_loss: 1.2487
# Epoch 18/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9464 - loss: 0.4570
# Epoch 18: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9417 - loss: 0.4582 - val_categorical_accuracy: 0.4778 - val_loss: 1.2522
# Epoch 19/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9539 - loss: 0.4306
# Epoch 19: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9550 - loss: 0.4255 - val_categorical_accuracy: 0.4500 - val_loss: 1.2672
# Epoch 20/300
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9585 - loss: 0.4149
# Epoch 20: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - categorical_accuracy: 0.9594 - loss: 0.4108 - val_categorical_accuracy: 0.4639 - val_loss: 1.2561
# Epoch 21/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9661 - loss: 0.3858
# Epoch 21: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9628 - loss: 0.3884 - val_categorical_accuracy: 0.4472 - val_loss: 1.2686
# Epoch 22/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9585 - loss: 0.3805
# Epoch 22: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9678 - loss: 0.3624 - val_categorical_accuracy: 0.4639 - val_loss: 1.2718
# Epoch 23/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9765 - loss: 0.3431
# Epoch 23: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9772 - loss: 0.3413 - val_categorical_accuracy: 0.4528 - val_loss: 1.2689
# Epoch 24/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9821 - loss: 0.3309
# Epoch 24: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9794 - loss: 0.3281 - val_categorical_accuracy: 0.4444 - val_loss: 1.2751
# Epoch 25/300
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9782 - loss: 0.3114
# Epoch 25: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9756 - loss: 0.3132 - val_categorical_accuracy: 0.4444 - val_loss: 1.2782
# Epoch 26/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9868 - loss: 0.2901
# Epoch 26: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9861 - loss: 0.2908 - val_categorical_accuracy: 0.4500 - val_loss: 1.2928
# Epoch 27/300
# 55/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9815 - loss: 0.2752
# Epoch 27: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9839 - loss: 0.2774 - val_categorical_accuracy: 0.4444 - val_loss: 1.2901
# Epoch 28/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9863 - loss: 0.2712
# Epoch 28: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9878 - loss: 0.2707 - val_categorical_accuracy: 0.4417 - val_loss: 1.2971
# Epoch 29/300
# 48/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9880 - loss: 0.2535
# Epoch 29: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9878 - loss: 0.2530 - val_categorical_accuracy: 0.4611 - val_loss: 1.3042
# Epoch 30/300
# 53/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9918 - loss: 0.2445
# Epoch 30: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9900 - loss: 0.2395 - val_categorical_accuracy: 0.4417 - val_loss: 1.3143
# Epoch 31/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9919 - loss: 0.2411
# Epoch 31: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9911 - loss: 0.2423 - val_categorical_accuracy: 0.4472 - val_loss: 1.3125
# Epoch 32/300
# 53/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9948 - loss: 0.2184
# Epoch 32: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9928 - loss: 0.2212 - val_categorical_accuracy: 0.4250 - val_loss: 1.3269
# Epoch 33/300
# 54/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9943 - loss: 0.2218
# Epoch 33: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9922 - loss: 0.2174 - val_categorical_accuracy: 0.4389 - val_loss: 1.3188
# Epoch 34/300
# 55/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9933 - loss: 0.2064
# Epoch 34: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9922 - loss: 0.2090 - val_categorical_accuracy: 0.4389 - val_loss: 1.3266
# Epoch 35/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9973 - loss: 0.1943
# Epoch 35: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9944 - loss: 0.2040 - val_categorical_accuracy: 0.4361 - val_loss: 1.3393
# Epoch 36/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9948 - loss: 0.1834
# Epoch 36: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9944 - loss: 0.1850 - val_categorical_accuracy: 0.4306 - val_loss: 1.3577
# Epoch 37/300
# 53/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9949 - loss: 0.1847
# Epoch 37: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9939 - loss: 0.1859 - val_categorical_accuracy: 0.4306 - val_loss: 1.3442
# Epoch 38/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9935 - loss: 0.1807
# Epoch 38: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9922 - loss: 0.1821 - val_categorical_accuracy: 0.4222 - val_loss: 1.3514
# Epoch 39/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9970 - loss: 0.1728
# Epoch 39: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9939 - loss: 0.1727 - val_categorical_accuracy: 0.4389 - val_loss: 1.3519
# Epoch 40/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9961 - loss: 0.1675
# Epoch 40: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9961 - loss: 0.1678 - val_categorical_accuracy: 0.4306 - val_loss: 1.3546
# Epoch 41/300
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9949 - loss: 0.1629
# Epoch 41: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9939 - loss: 0.1612 - val_categorical_accuracy: 0.4333 - val_loss: 1.3735
# Epoch 42/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9968 - loss: 0.1573
# Epoch 42: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9972 - loss: 0.1611 - val_categorical_accuracy: 0.4306 - val_loss: 1.3715
# Epoch 43/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9955 - loss: 0.1538
# Epoch 43: val_categorical_accuracy did not improve from 0.48056
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9939 - loss: 0.1535 - val_categorical_accuracy: 0.4278 - val_loss: 1.3732
# Epoch 43: early stopping

# %% [markdown]
# ## Model testing

# %%
best_model = tf.keras.models.load_model(bestModel)
yhat = np.argmax(best_model.predict(x_test), axis=1)
ytrue = np.argmax(y_test, axis=1)
print('test acc: {:.2f}%'.format(np.sum(yhat == ytrue) / yts.shape[0] * 100))
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# test acc: 46.39%

# %%
target_names = ['open one hand', 'imagine open one hand', 'open both hands/feet', 'imagine open both hands/feet']
print(classification_report(ytrue, yhat, target_names=target_names, digits=4))
# Out:
#                               precision    recall  f1-score   support
#
#                open one hand     0.5593    0.3667    0.4430        90
#        imagine open one hand     0.4414    0.5444    0.4876        90
#         open both hands/feet     0.4648    0.3667    0.4099        90
# imagine open both hands/feet     0.4370    0.5778    0.4976        90
#
#                     accuracy                         0.4639       360
#                    macro avg     0.4756    0.4639    0.4595       360
#                 weighted avg     0.4756    0.4639    0.4595       360

# %%
cm = confusion_matrix(ytrue, yhat)
cm
# Out:
# array([[33, 28, 17, 12],
#        [12, 49,  7, 22],
#        [ 9, 15, 33, 33],
#        [ 5, 19, 14, 52]])

# %%
plot_confusion_matrix(cm, ['Task1', 'Task2', 'Task3', 'Task4'], normalize=True, title='Confusion matrix', cmap=plt.cm.Greys)
# Out:
# Normalized confusion matrix
# [[0.36666667 0.31111111 0.18888889 0.13333333]
#  [0.13333333 0.54444444 0.07777778 0.24444444]
#  [0.1        0.16666667 0.36666667 0.36666667]
#  [0.05555556 0.21111111 0.15555556 0.57777778]]
