# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"

import tensorflow.compat.v1 as tf

tf.config.set_soft_device_placement(True)
# tf.debugging.set_log_device_placement(True)
# from sklearn.metrics import confusion_matrix
import numpy as np
# from scipy.io import loadmat
# from functools import reduce
# from scipy import signal
import pandas as pd
# from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow import keras as K
from tensorflow.keras.layers import Add, Dense, Activation, Flatten, concatenate, Input, Dropout, LSTM, Conv2D, MaxPooling2D, Conv1D, MaxPooling1D, BatchNormalization, PReLU, ELU, ReLU
from tensorflow.keras.models import Sequential, Model, load_model
import matplotlib.pyplot as plt
# import datetime
# get_ipython().run_line_magic('load_ext', 'tensorboard')
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# get_ipython().run_line_magic('matplotlib', 'inline')
# from collections import Counter 
np_load_old = np.load
# from tensorflow.keras.utils import plot_model
from tensorflow.keras.initializers import glorot_uniform
# modify the default parameters of np.load
np.load = lambda *a,**k: np_load_old(*a, allow_pickle=True, **k)
np.random.seed(42)
tf.set_random_seed(42)
from sklearn.metrics import classification_report
import argparse
import h5py
from sklearn.metrics import confusion_matrix
import itertools
import math
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1773958285.312957  193860 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.figure(figsize=(15,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=36)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=30)
    plt.yticks(tick_marks, classes, fontsize=30)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black", fontsize=28)

    plt.tight_layout()
    plt.ylabel('True label', fontsize=30)
    plt.xlabel('Predicted label', fontsize=30)

# %% [markdown]
# ## Load in data

# %%
# load new train, validation, and test datasets
loadPath = '/home/sz4544/EEG-motor-imagery-main/project/'
os.makedirs(os.path.join(loadPath, "models"), exist_ok=True)
bestModel = '/home/sz4544/EEG-motor-imagery-main/project/models/ftsurrogate_full_dataset_2CNN.keras'

f_train = h5py.File(os.path.join(loadPath, "train12720_raw_EEG.h5"), "r")
tr_data = f_train['data'][:]
ytr = f_train['tasks'][:]
tr_subjects = f_train['subjects'][:]

f_valid = h5py.File(os.path.join(loadPath, "valid2544_raw_EEG.h5"), "r")
val_data = f_valid['data'][:]
yval = f_valid['tasks'][:]
val_subjects = f_valid['subjects'][:]

f_test = h5py.File(os.path.join(loadPath, "test2544_raw_EEG.h5"), "r")
ts_data = f_test['data'][:]
yts = f_test['tasks'][:]
ts_subjects = f_test['subjects'][:]

# %% [markdown]
# ## Normalization

# %%
# flatten and reshape data
xtr_s_flattened = np.squeeze(tr_data).ravel().reshape((-1, 64))
xval_s_flattened = np.squeeze(val_data).ravel().reshape((-1, 64))
xts_s_flattened = np.squeeze(ts_data).ravel().reshape((-1, 64))
print(xtr_s_flattened.shape)
print(xval_s_flattened.shape)
print(xts_s_flattened.shape)

# normalize data
scaler = StandardScaler()
Ztr_temp = scaler.fit_transform(xtr_s_flattened)
Zval_temp = scaler.transform(xval_s_flattened)
Zts_temp = scaler.transform(xts_s_flattened)

# flatten and reshape data back
Ztr = np.squeeze(Ztr_temp).ravel().reshape((-1, 640, 64))
Zval = np.squeeze(Zval_temp).ravel().reshape((-1, 640, 64))
Zts = np.squeeze(Zts_temp).ravel().reshape((-1, 640, 64))
print(Ztr.shape)
print(Zval.shape)
print(Zts.shape)
# Out:
# (8140800, 64)
# (1628160, 64)
# (1628160, 64)
# (12720, 640, 64)
# (2544, 640, 64)
# (2544, 640, 64)

# %%
x_train = Ztr[..., np.newaxis].astype(np.float32)
x_valid = Zval[..., np.newaxis].astype(np.float32)
x_test = Zts[..., np.newaxis].astype(np.float32)
y_train = pd.get_dummies(ytr).values.astype(np.float32)
y_valid = pd.get_dummies(yval).values.astype(np.float32)
y_test = pd.get_dummies(yts).values.astype(np.float32)

# FT surrogate augmentation: only applied to training data
# For EEG with important spatial structure, use channel_indep=False

def ft_surrogate_batch(X, phase_noise_magnitude=0.25, channel_indep=False, random_state=42):
    rng = np.random.default_rng(random_state)
    X_aug = np.empty_like(X, dtype=np.float32)

    n_samples, n_times, n_channels, _ = X.shape

    for i in range(n_samples):
        x = X[i, :, :, 0]  # shape: (n_times, n_channels)

        # FFT along time axis
        Xf = np.fft.rfft(x, axis=0)
        n_freqs = Xf.shape[0]

        # Sample phase noise
        if channel_indep:
            phase_noise = rng.uniform(
                low=0.0,
                high=phase_noise_magnitude * 2 * np.pi,
                size=(n_freqs, n_channels)
            )
        else:
            shared_phase = rng.uniform(
                low=0.0,
                high=phase_noise_magnitude * 2 * np.pi,
                size=(n_freqs, 1)
            )
            phase_noise = np.repeat(shared_phase, n_channels, axis=1)

        # Keep DC and Nyquist (if present) unchanged
        phase_noise[0, :] = 0.0
        if n_times % 2 == 0:
            phase_noise[-1, :] = 0.0

        # Apply phase perturbation and invert FFT
        Xf_aug = Xf * np.exp(1j * phase_noise)
        x_aug = np.fft.irfft(Xf_aug, n=n_times, axis=0).astype(np.float32)

        X_aug[i, :, :, 0] = x_aug

    return X_aug

phase_noise_magnitude = 0.25
channel_indep = False

x_train_ft = ft_surrogate_batch(
    x_train,
    phase_noise_magnitude=phase_noise_magnitude,
    channel_indep=channel_indep,
    random_state=42
)

# True augmentation: original training samples + FT-surrogate samples
x_train_aug = np.concatenate([x_train, x_train_ft], axis=0).astype(np.float32)
y_train_aug = np.concatenate([y_train, y_train], axis=0).astype(np.float32)

print("tr_data shape:", tr_data.shape)
print("val_data shape:", val_data.shape)
print("ts_data shape:", ts_data.shape)

print("x_train shape:", x_train.shape)
print("x_train_ft shape:", x_train_ft.shape)
print("x_train_aug shape:", x_train_aug.shape)

print("x_valid shape:", x_valid.shape)
print("x_test shape:", x_test.shape)

print("y_train shape:", y_train.shape)
print("y_train_aug shape:", y_train_aug.shape)
print("y_valid shape:", y_valid.shape)
print("y_test shape:", y_test.shape)

print("phase_noise_magnitude:", phase_noise_magnitude)
print("channel_indep:", channel_indep)
# Out:
# tr_data shape: (12720, 640, 64)
# val_data shape: (2544, 640, 64)
# ts_data shape: (2544, 640, 64)
# x_train shape: (12720, 640, 64, 1)
# x_train_ft shape: (12720, 640, 64, 1)
# x_train_aug shape: (25440, 640, 64, 1)
# x_valid shape: (2544, 640, 64, 1)
# x_test shape: (2544, 640, 64, 1)
# y_train shape: (12720, 4)
# y_train_aug shape: (25440, 4)
# y_valid shape: (2544, 4)
# y_test shape: (2544, 4)
# phase_noise_magnitude: 0.25
# channel_indep: False

# %% [markdown]
# ## Model architecture

# %%
class EEGSequence(K.utils.Sequence):
    def __init__(self, x, y, batch_size=32, shuffle=True):
        self.x = x
        self.y = y
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indices = np.arange(len(self.x))
        self.on_epoch_end()

    def __len__(self):
        return math.ceil(len(self.x) / self.batch_size)

    def __getitem__(self, idx):
        batch_idx = self.indices[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_x = self.x[batch_idx]
        batch_y = self.y[batch_idx]
        return batch_x, batch_y

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)


train_seq = EEGSequence(x_train_aug, y_train_aug, batch_size=32, shuffle=True)
valid_seq = EEGSequence(x_valid, y_valid, batch_size=32, shuffle=False)
test_seq  = EEGSequence(x_test, y_test, batch_size=32, shuffle=False)

# %%
nodes = 640
inputs = Input(shape=(nodes, 64, 1))

conv1 = Conv2D(8, (15,9), strides=(2,1), kernel_initializer=glorot_uniform(seed=42))(inputs)
batch1 = BatchNormalization()(conv1)
prelu1 = PReLU()(batch1)
maxpool1 = MaxPooling2D((2,2))(prelu1)

conv2 = Conv2D(16, (15,9), strides=(2,1), kernel_initializer=glorot_uniform(seed=42))(maxpool1)
batch2 = BatchNormalization()(conv2)
prelu2 = PReLU()(batch2)

flat = Flatten()(prelu2)
dense1 = Dense(16, activation='sigmoid', kernel_initializer=glorot_uniform(seed=42))(flat)
drop1 = Dropout(0.2)(dense1)
predictions = Dense(4, activation='softmax', kernel_initializer=glorot_uniform(seed=42))(drop1)

model = Model(inputs=inputs, outputs=predictions)
print(model.summary())

opt_adam = K.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
model.compile(loss='categorical_crossentropy', optimizer=opt_adam, metrics=['categorical_accuracy'])
# Out:
# I0000 00:00:1773958300.028451  193860 gpu_process_state.cc:208] Using CUDA malloc Async allocator for GPU: 0
# I0000 00:00:1773958300.028743  193860 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 734 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:41:00.0, compute capability: 8.9
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 640, 64, 1)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 313, 56, 8)     │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 313, 56, 8)     │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ p_re_lu (PReLU)                 │ (None, 313, 56, 8)     │       140,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 156, 28, 8)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 71, 20, 16)     │        17,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 71, 20, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ p_re_lu_1 (PReLU)               │ (None, 71, 20, 16)     │        22,720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 22720)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │       363,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            68 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 545,028 (2.08 MB)
#  Trainable params: 544,980 (2.08 MB)
#  Non-trainable params: 48 (192.00 B)
# None

# %%
es = EarlyStopping(monitor='val_categorical_accuracy', mode='max', verbose=1, patience=30)
mc = ModelCheckpoint(bestModel, monitor='val_categorical_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
history = model.fit(
    train_seq,
    epochs=300,
    verbose=1,
    validation_data=valid_seq,
    callbacks=[es, mc]
)
# Out:
# Epoch 1/300
# /home/sz4544/miniconda3/envs/eeg_cnn/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# I0000 00:00:1773958300.636209  193860 generator_dataset_op.cc:213] Memory patch applied: M_TRIM_THRESHOLD=128 kb was set.
# I0000 00:00:1773958301.496981  194005 service.cc:153] XLA service 0x59cba3366180 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1773958301.497004  194005 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 4090, Compute Capability 8.9 (Driver: 12.4.0; Runtime: 12.8.0; Toolkit: 12.5.0; DNN: 9.8.0)
# I0000 00:00:1773958301.550103  194005 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1773958301.736800  194005 cuda_dnn.cc:461] Loaded cuDNN version 90800
# I0000 00:00:1773958301.778594  194005 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_2994__.41
#  22/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.2424 - loss: 1.4830
# I0000 00:00:1773958305.935502  194005 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 790/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3031 - loss: 1.3738
# Epoch 1: val_categorical_accuracy improved from None to 0.37186, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/ftsurrogate_full_dataset_2CNN.keras
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - categorical_accuracy: 0.3354 - loss: 1.3420 - val_categorical_accuracy: 0.3719 - val_loss: 1.2970
# Epoch 2/300
# 790/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3947 - loss: 1.2756
# Epoch 2: val_categorical_accuracy improved from 0.37186 to 0.38365, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/ftsurrogate_full_dataset_2CNN.keras
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.4039 - loss: 1.2621 - val_categorical_accuracy: 0.3836 - val_loss: 1.2723
# Epoch 3/300
# 791/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4419 - loss: 1.2122
# Epoch 3: val_categorical_accuracy improved from 0.38365 to 0.39662, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/ftsurrogate_full_dataset_2CNN.keras
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.4475 - loss: 1.2036 - val_categorical_accuracy: 0.3966 - val_loss: 1.2752
# Epoch 4/300
# 787/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4794 - loss: 1.1560
# Epoch 4: val_categorical_accuracy improved from 0.39662 to 0.42217, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/ftsurrogate_full_dataset_2CNN.keras
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.4878 - loss: 1.1456 - val_categorical_accuracy: 0.4222 - val_loss: 1.2530
# Epoch 5/300
# 787/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5322 - loss: 1.0859
# Epoch 5: val_categorical_accuracy did not improve from 0.42217
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.5296 - loss: 1.0883 - val_categorical_accuracy: 0.4088 - val_loss: 1.2501
# Epoch 6/300
# 792/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5715 - loss: 1.0215
# Epoch 6: val_categorical_accuracy did not improve from 0.42217
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - categorical_accuracy: 0.5693 - loss: 1.0261 - val_categorical_accuracy: 0.4163 - val_loss: 1.2452
# Epoch 7/300
# 789/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6053 - loss: 0.9710
# Epoch 7: val_categorical_accuracy did not improve from 0.42217
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.6045 - loss: 0.9730 - val_categorical_accuracy: 0.4147 - val_loss: 1.2546
# Epoch 8/300
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6419 - loss: 0.9098
# Epoch 8: val_categorical_accuracy improved from 0.42217 to 0.42256, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/ftsurrogate_full_dataset_2CNN.keras
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.6369 - loss: 0.9148 - val_categorical_accuracy: 0.4226 - val_loss: 1.2560
# Epoch 9/300
# 791/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6756 - loss: 0.8527
# Epoch 9: val_categorical_accuracy improved from 0.42256 to 0.43160, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/ftsurrogate_full_dataset_2CNN.keras
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.6717 - loss: 0.8565 - val_categorical_accuracy: 0.4316 - val_loss: 1.2691
# Epoch 10/300
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7087 - loss: 0.7907
# Epoch 10: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.7023 - loss: 0.7938 - val_categorical_accuracy: 0.4194 - val_loss: 1.3081
# Epoch 11/300
# 794/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7300 - loss: 0.7409
# Epoch 11: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.7283 - loss: 0.7428 - val_categorical_accuracy: 0.4281 - val_loss: 1.3244
# Epoch 12/300
# 787/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7570 - loss: 0.6893
# Epoch 12: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.7544 - loss: 0.6885 - val_categorical_accuracy: 0.4308 - val_loss: 1.3343
# Epoch 13/300
# 790/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7802 - loss: 0.6367
# Epoch 13: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.7776 - loss: 0.6366 - val_categorical_accuracy: 0.4245 - val_loss: 1.3607
# Epoch 14/300
# 792/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.8006 - loss: 0.5826
# Epoch 14: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.7989 - loss: 0.5854 - val_categorical_accuracy: 0.4143 - val_loss: 1.3914
# Epoch 15/300
# 789/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.8189 - loss: 0.5445
# Epoch 15: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.8178 - loss: 0.5443 - val_categorical_accuracy: 0.4210 - val_loss: 1.4345
# Epoch 16/300
# 791/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.8413 - loss: 0.4948
# Epoch 16: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.8354 - loss: 0.5018 - val_categorical_accuracy: 0.4233 - val_loss: 1.4834
# Epoch 17/300
# 793/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.8513 - loss: 0.4610
# Epoch 17: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.8462 - loss: 0.4697 - val_categorical_accuracy: 0.4076 - val_loss: 1.5151
# Epoch 18/300
# 788/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.8659 - loss: 0.4214
# Epoch 18: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - categorical_accuracy: 0.8619 - loss: 0.4305 - val_categorical_accuracy: 0.4068 - val_loss: 1.5730
# Epoch 19/300
# 788/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.8712 - loss: 0.4039
# Epoch 19: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - categorical_accuracy: 0.8693 - loss: 0.4045 - val_categorical_accuracy: 0.4123 - val_loss: 1.5824
# Epoch 20/300
# 789/795 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.8876 - loss: 0.3664
# Epoch 20: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - categorical_accuracy: 0.8865 - loss: 0.3673 - val_categorical_accuracy: 0.4182 - val_loss: 1.6254
# Epoch 21/300
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.8944 - loss: 0.3433
# Epoch 21: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - categorical_accuracy: 0.8918 - loss: 0.3479 - val_categorical_accuracy: 0.4104 - val_loss: 1.6734
# Epoch 22/300
# 793/795 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.9036 - loss: 0.3201
# Epoch 22: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - categorical_accuracy: 0.8994 - loss: 0.3245 - val_categorical_accuracy: 0.3982 - val_loss: 1.7763
# Epoch 23/300
# 790/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9126 - loss: 0.2942
# Epoch 23: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - categorical_accuracy: 0.9093 - loss: 0.2990 - val_categorical_accuracy: 0.4049 - val_loss: 1.7057
# Epoch 24/300
# 790/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9217 - loss: 0.2699
# Epoch 24: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.9162 - loss: 0.2788 - val_categorical_accuracy: 0.4041 - val_loss: 1.7886
# Epoch 25/300
# 794/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9273 - loss: 0.2522
# Epoch 25: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.9247 - loss: 0.2565 - val_categorical_accuracy: 0.4151 - val_loss: 1.8390
# Epoch 26/300
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9316 - loss: 0.2379
# Epoch 26: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.9272 - loss: 0.2437 - val_categorical_accuracy: 0.3990 - val_loss: 1.8919
# Epoch 27/300
# 789/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9367 - loss: 0.2186
# Epoch 27: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - categorical_accuracy: 0.9339 - loss: 0.2273 - val_categorical_accuracy: 0.3947 - val_loss: 2.0212
# Epoch 28/300
# 791/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9412 - loss: 0.2103
# Epoch 28: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - categorical_accuracy: 0.9399 - loss: 0.2113 - val_categorical_accuracy: 0.3990 - val_loss: 1.9401
# Epoch 29/300
# 790/795 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9434 - loss: 0.2014
# Epoch 29: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - categorical_accuracy: 0.9438 - loss: 0.2000 - val_categorical_accuracy: 0.4002 - val_loss: 2.0212
# Epoch 30/300
# 787/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9459 - loss: 0.1886
# Epoch 30: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.9447 - loss: 0.1921 - val_categorical_accuracy: 0.3978 - val_loss: 2.1498
# Epoch 31/300
# 787/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9538 - loss: 0.1665
# Epoch 31: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - categorical_accuracy: 0.9512 - loss: 0.1737 - val_categorical_accuracy: 0.3899 - val_loss: 2.2267
# Epoch 32/300
# 794/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9539 - loss: 0.1694
# Epoch 32: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.9532 - loss: 0.1704 - val_categorical_accuracy: 0.3962 - val_loss: 2.1874
# Epoch 33/300
# 789/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9577 - loss: 0.1586
# Epoch 33: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.9564 - loss: 0.1607 - val_categorical_accuracy: 0.3911 - val_loss: 2.1725
# Epoch 34/300
# 791/795 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9632 - loss: 0.1414
# Epoch 34: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - categorical_accuracy: 0.9606 - loss: 0.1465 - val_categorical_accuracy: 0.3974 - val_loss: 2.3540
# Epoch 35/300
# 787/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9616 - loss: 0.1394
# Epoch 35: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.9603 - loss: 0.1429 - val_categorical_accuracy: 0.3931 - val_loss: 2.2823
# Epoch 36/300
# 790/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9646 - loss: 0.1306
# Epoch 36: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.9619 - loss: 0.1363 - val_categorical_accuracy: 0.3939 - val_loss: 2.2639
# Epoch 37/300
# 793/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9655 - loss: 0.1272
# Epoch 37: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - categorical_accuracy: 0.9642 - loss: 0.1310 - val_categorical_accuracy: 0.3899 - val_loss: 2.5036
# Epoch 38/300
# 794/795 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9637 - loss: 0.1265
# Epoch 38: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - categorical_accuracy: 0.9632 - loss: 0.1279 - val_categorical_accuracy: 0.3950 - val_loss: 2.4572
# Epoch 39/300
# 791/795 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9707 - loss: 0.1115
# Epoch 39: val_categorical_accuracy did not improve from 0.43160
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - categorical_accuracy: 0.9675 - loss: 0.1183 - val_categorical_accuracy: 0.3927 - val_loss: 2.4076
# Epoch 39: early stopping

# %% [markdown]
# ## Model testing

# %%
best_model = tf.keras.models.load_model(bestModel)
yhat = np.argmax(best_model.predict(test_seq), axis=1)
ytrue = np.argmax(y_test, axis=1)
print('test acc: {:.2f}%'.format(np.sum(yhat == ytrue) / yts.shape[0] * 100))
# Out:
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# test acc: 43.47%

# %%
target_names = ['open one hand', 'imagine open one hand', 'open both hands/feet', 'imagine open both hands/feet']
print(classification_report(ytrue, yhat, target_names=target_names, digits=4))
# Out:
#                               precision    recall  f1-score   support
#
#                open one hand     0.4648    0.2799    0.3494       636
#        imagine open one hand     0.4197    0.4686    0.4428       636
#         open both hands/feet     0.4757    0.4465    0.4607       636
# imagine open both hands/feet     0.4052    0.5440    0.4644       636
#
#                     accuracy                         0.4347      2544
#                    macro avg     0.4413    0.4347    0.4293      2544
#                 weighted avg     0.4413    0.4347    0.4293      2544

# %%
cm = confusion_matrix(ytrue, yhat)
cm
# Out:
# array([[178, 212, 113, 133],
#        [ 97, 298,  65, 176],
#        [ 72,  81, 284, 199],
#        [ 36, 119, 135, 346]])

# %%
plot_confusion_matrix(cm, ['Task1', 'Task2', 'Task3', 'Task4'], normalize=True, title='Confusion matrix', cmap=plt.cm.Greys)
# Out:
# Normalized confusion matrix
# [[0.27987421 0.33333333 0.17767296 0.2091195 ]
#  [0.15251572 0.46855346 0.10220126 0.27672956]
#  [0.11320755 0.12735849 0.44654088 0.31289308]
#  [0.05660377 0.18710692 0.21226415 0.54402516]]
