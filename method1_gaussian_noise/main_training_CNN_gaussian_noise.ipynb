# %%
import tensorflow.compat.v1 as tf

tf.config.set_soft_device_placement(True)
# tf.debugging.set_log_device_placement(True)
# from sklearn.metrics import confusion_matrix
import numpy as np
# from scipy.io import loadmat
import os
# from functools import reduce
# from scipy import signal
import pandas as pd
# from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow import keras as K
from tensorflow.keras.layers import Add, Dense, Activation, Flatten, concatenate, Input, Dropout, LSTM, Conv2D, MaxPooling2D, Conv1D, MaxPooling1D, BatchNormalization, PReLU, ELU, ReLU
from tensorflow.keras.models import Sequential, Model, load_model
import matplotlib.pyplot as plt
# import datetime
# get_ipython().run_line_magic('load_ext', 'tensorboard')
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# get_ipython().run_line_magic('matplotlib', 'inline')
# from collections import Counter 
np_load_old = np.load
# from tensorflow.keras.utils import plot_model
from tensorflow.keras.initializers import glorot_uniform
# modify the default parameters of np.load
np.load = lambda *a,**k: np_load_old(*a, allow_pickle=True, **k)
np.random.seed(42)
tf.set_random_seed(42)
from sklearn.metrics import classification_report
import argparse
import h5py

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import itertools

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.figure(figsize=(15,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=36)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=30)
    plt.yticks(tick_marks, classes, fontsize=30)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black", fontsize=28)

    plt.tight_layout()
    plt.ylabel('True label', fontsize=30)
    plt.xlabel('Predicted label', fontsize=30)

# %% [markdown]
# ## Load in data

# %%
# load new train, validation, and test datasets
# load new train, validation, and test datasets
loadPath = '/home/sz4544/EEG-motor-imagery-main/project/'
os.makedirs(os.path.join(loadPath, "models"), exist_ok=True)
bestModel = '/home/sz4544/EEG-motor-imagery-main/project/models/gaussian_noise_tr1800-val360ts_2CNN.keras'

f_train = h5py.File(os.path.join(loadPath, "train1800_raw_EEG.h5"), "r")
tr_data = f_train['data'][:]
ytr = f_train['tasks'][:]
tr_subjects = f_train['subjects'][:]

f_valid = h5py.File(os.path.join(loadPath, "valid360_raw_EEG.h5"), "r")
val_data = f_valid['data'][:]
yval = f_valid['tasks'][:]
val_subjects = f_valid['subjects'][:]

f_test = h5py.File(os.path.join(loadPath, "test360_raw_EEG.h5"), "r")
ts_data = f_test['data'][:]
yts = f_test['tasks'][:]
ts_subjects = f_test['subjects'][:]

# %% [markdown]
# ## Normalization

# %%
# flatten and reshape data
xtr_s_flattened = np.squeeze(tr_data).ravel().reshape((-1, 64))
xval_s_flattened = np.squeeze(val_data).ravel().reshape((-1, 64))
xts_s_flattened = np.squeeze(ts_data).ravel().reshape((-1, 64))
print(xtr_s_flattened.shape)
print(xval_s_flattened.shape)
print(xts_s_flattened.shape)

# normalize data
scaler = StandardScaler()
Ztr_temp = scaler.fit_transform(xtr_s_flattened)
Zval_temp = scaler.transform(xval_s_flattened)
Zts_temp = scaler.transform(xts_s_flattened)

# flatten and reshape data back
Ztr = np.squeeze(Ztr_temp).ravel().reshape((-1, 640, 64))
Zval = np.squeeze(Zval_temp).ravel().reshape((-1, 640, 64))
Zts = np.squeeze(Zts_temp).ravel().reshape((-1, 640, 64))
print(Ztr.shape)
print(Zval.shape)
print(Zts.shape)
# Out:
# (1152000, 64)
# (230400, 64)
# (230400, 64)
# (1800, 640, 64)
# (360, 640, 64)
# (360, 640, 64)

# %%
x_train = Ztr[..., np.newaxis]
x_valid = Zval[..., np.newaxis]
x_test = Zts[..., np.newaxis]
y_train = pd.get_dummies(ytr).values
y_valid = pd.get_dummies(yval).values
y_test = pd.get_dummies(yts).values



# Gaussian noise augmentation: only applied to training data
noise_std = 0.05

x_train_aug = x_train + np.random.normal(
    loc=0.0,
    scale=noise_std,
    size=x_train.shape
)

y_train_aug = y_train.copy()

print("x_train shape:", x_train.shape)
print("x_train_aug shape:", x_train_aug.shape)
print("x_valid shape:", x_valid.shape)
print("x_test shape:", x_test.shape)
# Out:
# x_train shape: (1800, 640, 64, 1)
# x_train_aug shape: (1800, 640, 64, 1)
# x_valid shape: (360, 640, 64, 1)
# x_test shape: (360, 640, 64, 1)

# %%
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))

with strategy.scope():
    nodes = 640
    inputs = Input(shape=(nodes, 64, 1))

    conv1 = Conv2D(8, (15,9), strides=(2,1), kernel_initializer = glorot_uniform(seed=42))(inputs)
    batch1 = BatchNormalization()(conv1)
    prelu1 = PReLU()(batch1)
    maxpool1 = MaxPooling2D((2,2))(prelu1)
    conv2 = Conv2D(16, (15,9), strides=(2,1), kernel_initializer = glorot_uniform(seed=42))(maxpool1)
    batch2 = BatchNormalization()(conv2)
    prelu2 = PReLU()(batch2)
    # maxpool2 = MaxPooling2D((5,1))(prelu2)

    flat = Flatten()(prelu2)
    dense1 = Dense(16, activation='sigmoid', kernel_initializer = glorot_uniform(seed=42))(flat)
    drop1 = Dropout(0.2)(dense1)
    predictions = Dense(4, activation='softmax', kernel_initializer = glorot_uniform(seed=42))(drop1)
    model = Model(inputs=inputs,outputs=predictions)
print(model.summary())
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# Number of devices: 1
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 640, 64, 1)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 313, 56, 8)     │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 313, 56, 8)     │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ p_re_lu_6 (PReLU)               │ (None, 313, 56, 8)     │       140,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 156, 28, 8)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 71, 20, 16)     │        17,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 71, 20, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ p_re_lu_7 (PReLU)               │ (None, 71, 20, 16)     │        22,720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 22720)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 16)             │       363,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 4)              │            68 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 545,028 (2.08 MB)
#  Trainable params: 544,980 (2.08 MB)
#  Non-trainable params: 48 (192.00 B)
# None

# %%
with strategy.scope():
    opt_adam = K.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
    model.compile(loss='categorical_crossentropy', optimizer=opt_adam, metrics=['categorical_accuracy'])

es = EarlyStopping(monitor='val_categorical_accuracy', mode='max', verbose=1, patience=30)
mc = ModelCheckpoint(bestModel, monitor='val_categorical_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
history = model.fit(x=x_train_aug, y=y_train_aug, epochs=300, shuffle=True,
                    verbose=1, validation_data = (x_valid, y_valid), callbacks=[es, mc])
# Out:
# Epoch 1/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.2780 - loss: 1.4162
# Epoch 1: val_categorical_accuracy improved from None to 0.28611, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/gaussian_noise_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - categorical_accuracy: 0.2917 - loss: 1.3901 - val_categorical_accuracy: 0.2861 - val_loss: 1.3740
# Epoch 2/300
# 55/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.3960 - loss: 1.2938
# Epoch 2: val_categorical_accuracy improved from 0.28611 to 0.29167, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/gaussian_noise_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.3844 - loss: 1.3012 - val_categorical_accuracy: 0.2917 - val_loss: 1.3592
# Epoch 3/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.4543 - loss: 1.2236
# Epoch 3: val_categorical_accuracy improved from 0.29167 to 0.33889, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/gaussian_noise_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.4478 - loss: 1.2217 - val_categorical_accuracy: 0.3389 - val_loss: 1.3402
# Epoch 4/300
# 50/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.5227 - loss: 1.1356
# Epoch 4: val_categorical_accuracy improved from 0.33889 to 0.35278, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/gaussian_noise_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.5333 - loss: 1.1207 - val_categorical_accuracy: 0.3528 - val_loss: 1.3268
# Epoch 5/300
# 49/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5838 - loss: 1.0561
# Epoch 5: val_categorical_accuracy improved from 0.35278 to 0.36111, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/gaussian_noise_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.5906 - loss: 1.0472 - val_categorical_accuracy: 0.3611 - val_loss: 1.3088
# Epoch 6/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6376 - loss: 0.9797
# Epoch 6: val_categorical_accuracy improved from 0.36111 to 0.43333, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/gaussian_noise_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.6422 - loss: 0.9720 - val_categorical_accuracy: 0.4333 - val_loss: 1.2607
# Epoch 7/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6784 - loss: 0.9127
# Epoch 7: val_categorical_accuracy did not improve from 0.43333
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.6889 - loss: 0.9047 - val_categorical_accuracy: 0.4306 - val_loss: 1.2509
# Epoch 8/300
# 49/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.7246 - loss: 0.8517
# Epoch 8: val_categorical_accuracy improved from 0.43333 to 0.45278, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/gaussian_noise_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.7333 - loss: 0.8412 - val_categorical_accuracy: 0.4528 - val_loss: 1.2337
# Epoch 9/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.7726 - loss: 0.8023
# Epoch 9: val_categorical_accuracy improved from 0.45278 to 0.45833, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/gaussian_noise_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.7711 - loss: 0.7933 - val_categorical_accuracy: 0.4583 - val_loss: 1.2330
# Epoch 10/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.8036 - loss: 0.7492
# Epoch 10: val_categorical_accuracy did not improve from 0.45833
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.8094 - loss: 0.7354 - val_categorical_accuracy: 0.4472 - val_loss: 1.2408
# Epoch 11/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.8265 - loss: 0.7036
# Epoch 11: val_categorical_accuracy did not improve from 0.45833
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.8278 - loss: 0.6945 - val_categorical_accuracy: 0.4444 - val_loss: 1.2298
# Epoch 12/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.8407 - loss: 0.6650
# Epoch 12: val_categorical_accuracy did not improve from 0.45833
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.8556 - loss: 0.6493 - val_categorical_accuracy: 0.4417 - val_loss: 1.2339
# Epoch 13/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.8707 - loss: 0.6037
# Epoch 13: val_categorical_accuracy did not improve from 0.45833
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.8739 - loss: 0.6073 - val_categorical_accuracy: 0.4306 - val_loss: 1.2396
# Epoch 14/300
# 55/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.8948 - loss: 0.5898
# Epoch 14: val_categorical_accuracy did not improve from 0.45833
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.8972 - loss: 0.5808 - val_categorical_accuracy: 0.4528 - val_loss: 1.2432
# Epoch 15/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9174 - loss: 0.5455
# Epoch 15: val_categorical_accuracy improved from 0.45833 to 0.46389, saving model to /home/sz4544/EEG-motor-imagery-main/project/models/gaussian_noise_tr1800-val360ts_2CNN.keras
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9150 - loss: 0.5447 - val_categorical_accuracy: 0.4639 - val_loss: 1.2448
# Epoch 16/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9213 - loss: 0.5199
# Epoch 16: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9206 - loss: 0.5107 - val_categorical_accuracy: 0.4417 - val_loss: 1.2550
# Epoch 17/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9385 - loss: 0.4923
# Epoch 17: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9300 - loss: 0.4854 - val_categorical_accuracy: 0.4583 - val_loss: 1.2617
# Epoch 18/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9437 - loss: 0.4546
# Epoch 18: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9383 - loss: 0.4569 - val_categorical_accuracy: 0.4250 - val_loss: 1.2802
# Epoch 19/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9543 - loss: 0.4366
# Epoch 19: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9517 - loss: 0.4305 - val_categorical_accuracy: 0.4556 - val_loss: 1.2914
# Epoch 20/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9657 - loss: 0.4025
# Epoch 20: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9594 - loss: 0.3967 - val_categorical_accuracy: 0.4472 - val_loss: 1.2880
# Epoch 21/300
# 50/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9612 - loss: 0.3945
# Epoch 21: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9644 - loss: 0.3919 - val_categorical_accuracy: 0.4306 - val_loss: 1.2947
# Epoch 22/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9743 - loss: 0.3578
# Epoch 22: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9722 - loss: 0.3582 - val_categorical_accuracy: 0.4278 - val_loss: 1.3113
# Epoch 23/300
# 50/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9709 - loss: 0.3458
# Epoch 23: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9711 - loss: 0.3446 - val_categorical_accuracy: 0.4167 - val_loss: 1.3050
# Epoch 24/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9750 - loss: 0.3261
# Epoch 24: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9756 - loss: 0.3250 - val_categorical_accuracy: 0.4333 - val_loss: 1.2966
# Epoch 25/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9826 - loss: 0.3191
# Epoch 25: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9783 - loss: 0.3173 - val_categorical_accuracy: 0.4361 - val_loss: 1.3009
# Epoch 26/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9852 - loss: 0.2943
# Epoch 26: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9856 - loss: 0.2932 - val_categorical_accuracy: 0.4250 - val_loss: 1.3017
# Epoch 27/300
# 55/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9809 - loss: 0.2858
# Epoch 27: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9844 - loss: 0.2794 - val_categorical_accuracy: 0.4250 - val_loss: 1.3202
# Epoch 28/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9870 - loss: 0.2748
# Epoch 28: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9856 - loss: 0.2738 - val_categorical_accuracy: 0.4333 - val_loss: 1.3089
# Epoch 29/300
# 50/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9883 - loss: 0.2576
# Epoch 29: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9878 - loss: 0.2590 - val_categorical_accuracy: 0.4139 - val_loss: 1.3320
# Epoch 30/300
# 50/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9900 - loss: 0.2502
# Epoch 30: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9911 - loss: 0.2483 - val_categorical_accuracy: 0.4278 - val_loss: 1.3342
# Epoch 31/300
# 50/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9862 - loss: 0.2467
# Epoch 31: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9894 - loss: 0.2394 - val_categorical_accuracy: 0.4306 - val_loss: 1.3391
# Epoch 32/300
# 54/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9896 - loss: 0.2289
# Epoch 32: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9911 - loss: 0.2235 - val_categorical_accuracy: 0.4333 - val_loss: 1.3273
# Epoch 33/300
# 55/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9946 - loss: 0.2181
# Epoch 33: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9956 - loss: 0.2147 - val_categorical_accuracy: 0.4417 - val_loss: 1.3460
# Epoch 34/300
# 49/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9904 - loss: 0.2004
# Epoch 34: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9944 - loss: 0.2033 - val_categorical_accuracy: 0.4333 - val_loss: 1.3428
# Epoch 35/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9926 - loss: 0.2060
# Epoch 35: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9906 - loss: 0.2054 - val_categorical_accuracy: 0.4361 - val_loss: 1.3500
# Epoch 36/300
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9932 - loss: 0.1924
# Epoch 36: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9956 - loss: 0.1899 - val_categorical_accuracy: 0.4361 - val_loss: 1.3513
# Epoch 37/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9938 - loss: 0.1944
# Epoch 37: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9939 - loss: 0.1878 - val_categorical_accuracy: 0.4222 - val_loss: 1.3582
# Epoch 38/300
# 55/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9958 - loss: 0.1873
# Epoch 38: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9961 - loss: 0.1793 - val_categorical_accuracy: 0.4417 - val_loss: 1.3530
# Epoch 39/300
# 54/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9966 - loss: 0.1804
# Epoch 39: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9978 - loss: 0.1723 - val_categorical_accuracy: 0.4278 - val_loss: 1.3678
# Epoch 40/300
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9904 - loss: 0.1709
# Epoch 40: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9933 - loss: 0.1677 - val_categorical_accuracy: 0.4250 - val_loss: 1.3769
# Epoch 41/300
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.9959 - loss: 0.1656
# Epoch 41: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.9967 - loss: 0.1603 - val_categorical_accuracy: 0.4222 - val_loss: 1.3859
# Epoch 42/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9934 - loss: 0.1649
# Epoch 42: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9944 - loss: 0.1572 - val_categorical_accuracy: 0.4222 - val_loss: 1.3975
# Epoch 43/300
# 53/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9906 - loss: 0.1620
# Epoch 43: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.9944 - loss: 0.1549 - val_categorical_accuracy: 0.4222 - val_loss: 1.3957
# Epoch 44/300
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9975 - loss: 0.1509
# Epoch 44: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9967 - loss: 0.1464 - val_categorical_accuracy: 0.4250 - val_loss: 1.3919
# Epoch 45/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9954 - loss: 0.1415
# Epoch 45: val_categorical_accuracy did not improve from 0.46389
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.9967 - loss: 0.1369 - val_categorical_accuracy: 0.4194 - val_loss: 1.3973
# Epoch 45: early stopping

# %% [markdown]
# ## Model testing

# %%
best_model = tf.keras.models.load_model(bestModel)
yhat = np.argmax(best_model.predict(x_test), axis=1)
ytrue = np.argmax(y_test, axis=1)
print('test acc: {:.2f}%'.format(np.sum(yhat == ytrue) / yts.shape[0] * 100))
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# test acc: 46.11%

# %%
target_names = ['open one hand', 'imagine open one hand', 'open both hands/feet', 'imagine open both hands/feet']
print(classification_report(ytrue, yhat, target_names=target_names, digits=4))
# Out:
#                               precision    recall  f1-score   support
#
#                open one hand     0.4844    0.3444    0.4026        90
#        imagine open one hand     0.3769    0.5444    0.4455        90
#         open both hands/feet     0.5341    0.5222    0.5281        90
# imagine open both hands/feet     0.5000    0.4333    0.4643        90
#
#                     accuracy                         0.4611       360
#                    macro avg     0.4738    0.4611    0.4601       360
#                 weighted avg     0.4738    0.4611    0.4601       360

# %%
cm = confusion_matrix(ytrue, yhat)
cm
# Out:
# array([[31, 35, 16,  8],
#        [14, 49, 10, 17],
#        [10, 19, 47, 14],
#        [ 9, 27, 15, 39]])

# %%
plot_confusion_matrix(cm, ['Task1', 'Task2', 'Task3', 'Task4'], normalize=True, title='Confusion matrix', cmap=plt.cm.Greys)
# Out:
# Normalized confusion matrix
# [[0.34444444 0.38888889 0.17777778 0.08888889]
#  [0.15555556 0.54444444 0.11111111 0.18888889]
#  [0.11111111 0.21111111 0.52222222 0.15555556]
#  [0.1        0.3        0.16666667 0.43333333]]
